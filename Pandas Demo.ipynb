# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='ResponseId')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='qname')

# %%
pd.set_option('display.max_columns', 48)
pd.set_option('display.max_rows', 48)

# %%
df.sort_index(inplace=True)
schema_df.sort_index(inplace=True)

# %%
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# 3                                          Student, full-time
# 4                                          Employed full-time
# 5           Independent contractor, freelancer, or self-em...
# ...                                                       ...
# 83435                                      Employed full-time
# 83436       Independent contractor, freelancer, or self-em...
# 83437                                      Employed full-time
# 83438                                      Employed full-time
# 83439                                      Employed full-time
#
#                                                       Country    US_State  \
# ResponseId
# 1                                                    Slovakia         NaN
# 2                                                 Netherlands         NaN
# 3                                          Russian Federation         NaN
# 4                                                     Austria         NaN
# 5           United Kingdom of Great Britain and Northern I...         NaN
# ...                                                       ...         ...
# 83435                                United States of America       Texas
# 83436                                                   Benin         NaN
# 83437                                United States of America  New Jersey
# 83438                                                  Canada         NaN
# 83439                                                  Brazil         NaN
#
#            UK_Country                                            EdLevel  \
# ResponseId
# 1                 NaN  Secondary school (e.g. American high school, G...
# 2                 NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3                 NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4                 NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5             England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...               ...                                                ...
# 83435             NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83436             NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83437             NaN  Secondary school (e.g. American high school, G...
# 83438             NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83439             NaN                 Professional degree (JD, MD, etc.)
#
#                Age1stCode                                          LearnCode  \
# ResponseId
# 1           18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 2           11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3           11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 4           11 - 17 years                                                NaN
# 5            5 - 10 years                            Friend or family member
# ...                   ...                                                ...
# 83435       11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83436       11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83437       11 - 17 years                                             School
# 83438       11 - 17 years  Online Courses or Certification;Books / Physic...
# 83439       11 - 17 years                                             School
#
#            YearsCode YearsCodePro  \
# ResponseId
# 1                NaN          NaN
# 2                  7          NaN
# 3                NaN          NaN
# 4                NaN          NaN
# 5                 17           10
# ...              ...          ...
# 83435              6            5
# 83436              4            2
# 83437             10            4
# 83438              5            3
# 83439             14            4
#
#                                                       DevType  \
# ResponseId
# 1                                           Developer, mobile
# 2                                                         NaN
# 3                                                         NaN
# 4                                        Developer, front-end
# 5           Developer, desktop or enterprise applications;...
# ...                                                       ...
# 83435                                     Developer, back-end
# 83436                                   Developer, full-stack
# 83437       Data scientist or machine learning specialist;...
# 83438                                     Developer, back-end
# 83439       Developer, front-end;Developer, full-stack;Dev...
#
#                                                       OrgSize  \
# ResponseId
# 1                                          20 to 99 employees
# 2                                                         NaN
# 3                                                         NaN
# 4                                        100 to 499 employees
# 5           Just me - I am a freelancer, sole proprietor, ...
# ...                                                       ...
# 83435                                      20 to 99 employees
# 83436       Just me - I am a freelancer, sole proprietor, ...
# 83437                                10,000 or more employees
# 83438                                      20 to 99 employees
# 83439                                            I don’t know
#
#                                Currency  CompTotal CompFreq  \
# ResponseId
# 1                     EUR European Euro     4800.0  Monthly
# 2                                   NaN        NaN      NaN
# 3                                   NaN        NaN      NaN
# 4                     EUR European Euro        NaN  Monthly
# 5                   GBP\tPound sterling        NaN      NaN
# ...                                 ...        ...      ...
# 83435         USD\tUnited States dollar   160500.0   Yearly
# 83436       XOF\tWest African CFA franc   200000.0  Monthly
# 83437         USD\tUnited States dollar     1800.0   Weekly
# 83438              CAD\tCanadian dollar    90000.0  Monthly
# 83439               BRL\tBrazilian real     7700.0  Monthly
#
#                                    LanguageHaveWorkedWith  \
# ResponseId
# 1           C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 2                                       JavaScript;Python
# 3                                Assembly;C;Python;R;Rust
# 4                                   JavaScript;TypeScript
# 5                          Bash/Shell;HTML/CSS;Python;SQL
# ...                                                   ...
# 83435                                  Clojure;Kotlin;SQL
# 83436                                                 NaN
# 83437                                  Groovy;Java;Python
# 83438                Bash/Shell;JavaScript;Node.js;Python
# 83439              Delphi;Elixir;HTML/CSS;Java;JavaScript
#
#                                        LanguageWantToWorkWith  \
# ResponseId
# 1                                                       Swift
# 2                                                         NaN
# 3                                           Julia;Python;Rust
# 4                                       JavaScript;TypeScript
# 5                              Bash/Shell;HTML/CSS;Python;SQL
# ...                                                       ...
# 83435                                                 Clojure
# 83436                                                     NaN
# 83437                                             Java;Python
# 83438                                                 Go;Rust
# 83439       Elixir;HTML/CSS;Java;JavaScript;Node.js;PHP;SQ...
#
#                                       DatabaseHaveWorkedWith  \
# ResponseId
# 1                                          PostgreSQL;SQLite
# 2                                                 PostgreSQL
# 3                                                     SQLite
# 4                                                        NaN
# 5                             Elasticsearch;PostgreSQL;Redis
# ...                                                      ...
# 83435                                          Oracle;SQLite
# 83436         Firebase;MariaDB;MySQL;PostgreSQL;Redis;SQLite
# 83437        DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83438       Cassandra;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83439                                      Oracle;PostgreSQL
#
#                                        DatabaseWantToWorkWith  \
# ResponseId
# 1                                                      SQLite
# 2                                                         NaN
# 3                                                      SQLite
# 4                                                         NaN
# 5                    Cassandra;Elasticsearch;PostgreSQL;Redis
# ...                                                       ...
# 83435                                                  SQLite
# 83436       Firebase;MariaDB;MongoDB;MySQL;PostgreSQL;Redi...
# 83437                                          DynamoDB;Redis
# 83438                                                     NaN
# 83439       Elasticsearch;MongoDB;MySQL;Oracle;PostgreSQL;...
#
#                PlatformHaveWorkedWith PlatformWantToWorkWith  \
# ResponseId
# 1                                 NaN                    NaN
# 2                                 NaN                    NaN
# 3                              Heroku                    NaN
# 4                                 NaN                    NaN
# 5                                 NaN                    NaN
# ...                               ...                    ...
# 83435                             AWS                    AWS
# 83436                             NaN                    NaN
# 83437       AWS;Google Cloud Platform                    AWS
# 83438                          Heroku       AWS;DigitalOcean
# 83439                 Microsoft Azure                    AWS
#
#                                   WebframeHaveWorkedWith  \
# ResponseId
# 1                                        Laravel;Symfony
# 2                                   Angular;Flask;Vue.js
# 3                                                  Flask
# 4                                         Angular;jQuery
# 5                                                  Flask
# ...                                                  ...
# 83435                                                NaN
# 83436       Django;jQuery;Laravel;React.js;Ruby on Rails
# 83437                                      FastAPI;Flask
# 83438                      Django;Express;Flask;React.js
# 83439                                     Angular;Spring
#
#                                        WebframeWantToWorkWith  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3                                                       Flask
# 4                                              Angular;jQuery
# 5                                                       Flask
# ...                                                       ...
# 83435                                                     NaN
# 83436       Django;Express;jQuery;Laravel;React.js;Ruby on...
# 83437                                           FastAPI;Flask
# 83438                                                     NaN
# 83439                          Express;Laravel;Spring;Symfony
#
#                            MiscTechHaveWorkedWith  \
# ResponseId
# 1                                             NaN
# 2                                         Cordova
# 3           NumPy;Pandas;TensorFlow;Torch/PyTorch
# 4                                             NaN
# 5                Apache Spark;Hadoop;NumPy;Pandas
# ...                                           ...
# 83435                                         NaN
# 83436                                  Flutter;Qt
# 83437                   Hadoop;Keras;NumPy;Pandas
# 83438       NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83439                                         NaN
#
#                                        MiscTechWantToWorkWith  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3                 Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 4                                                         NaN
# 5                                         Hadoop;NumPy;Pandas
# ...                                                       ...
# 83435                                                     NaN
# 83436                                                     NaN
# 83437       Apache Spark;Hadoop;Keras;NumPy;Pandas;TensorFlow
# 83438                   NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83439                                                     NaN
#
#                  ToolsTechHaveWorkedWith          ToolsTechWantToWorkWith  \
# ResponseId
# 1                                    NaN                              NaN
# 2                        Docker;Git;Yarn                              Git
# 3                                    NaN                              NaN
# 4                                    NaN                              NaN
# 5             Docker;Git;Kubernetes;Yarn       Docker;Git;Kubernetes;Yarn
# ...                                  ...                              ...
# 83435                         Docker;Git                   Git;Kubernetes
# 83436         Git;Unity 3D;Unreal Engine            Docker;Git;Kubernetes
# 83437       Ansible;Docker;Git;Terraform  Docker;Git;Kubernetes;Terraform
# 83438       Ansible;Docker;Git;Terraform             Kubernetes;Terraform
# 83439                         Docker;Git            Docker;Git;Kubernetes
#
#                                  NEWCollabToolsHaveWorkedWith  \
# ResponseId
# 1                                              PHPStorm;Xcode
# 2                   Android Studio;IntelliJ;Notepad++;PyCharm
# 3           IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 4                                                         NaN
# 5                  Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
# ...                                                       ...
# 83435            IntelliJ;Sublime Text;Vim;Visual Studio Code
# 83436       Android Studio;Eclipse;Emacs;IntelliJ;NetBeans...
# 83437       Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
# 83438                                    PyCharm;Sublime Text
# 83439                             IntelliJ;Visual Studio Code
#
#                                  NEWCollabToolsWantToWorkWith        OpSys  \
# ResponseId
# 1                                                  Atom;Xcode        MacOS
# 2                                                         NaN      Windows
# 3           IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 4                                                         NaN      Windows
# 5           Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
# ...                                                       ...          ...
# 83435                                        Sublime Text;Vim        MacOS
# 83436       Emacs;IntelliJ;PHPStorm;PyCharm;RStudio;Sublim...  Linux-based
# 83437                  IntelliJ;IPython/Jupyter;Notepad++;Vim      Windows
# 83438                                                     NaN        MacOS
# 83439                    IntelliJ;PHPStorm;Visual Studio Code  Linux-based
#
#                                                      NEWStuck  \
# ResponseId
# 1           Call a coworker or friend;Visit Stack Overflow...
# 2                              Visit Stack Overflow;Google it
# 3           Visit Stack Overflow;Google it;Watch help / tu...
# 4           Call a coworker or friend;Visit Stack Overflow...
# 5           Visit Stack Overflow;Go for a walk or other ph...
# ...                                                       ...
# 83435                     Call a coworker or friend;Google it
# 83436       Call a coworker or friend;Visit Stack Overflow...
# 83437       Call a coworker or friend;Visit Stack Overflow...
# 83438       Call a coworker or friend;Visit Stack Overflow...
# 83439       Call a coworker or friend;Visit Stack Overflow...
#
#                                                    NEWSOSites  \
# ResponseId
# 1                                              Stack Overflow
# 2                                              Stack Overflow
# 3                               Stack Overflow;Stack Exchange
# 4                                              Stack Overflow
# 5                               Stack Overflow;Stack Exchange
# ...                                                       ...
# 83435                           Stack Overflow;Stack Exchange
# 83436                           Stack Overflow;Stack Exchange
# 83437                           Stack Overflow;Stack Exchange
# 83438                                          Stack Overflow
# 83439       Stack Overflow;Stack Exchange;Stack Overflow f...
#
#                                 SOVisitFreq SOAccount  \
# ResponseId
# 1                    Multiple times per day       Yes
# 2                     Daily or almost daily       Yes
# 3                    Multiple times per day       Yes
# 4                     Daily or almost daily       Yes
# 5                     Daily or almost daily       Yes
# ...                                     ...       ...
# 83435                  A few times per week        No
# 83436                Multiple times per day       Yes
# 83437                  A few times per week       Yes
# 83438       A few times per month or weekly       Yes
# 83439                  A few times per week       Yes
#
#                                                    SOPartFreq  \
# ResponseId
# 1                             A few times per month or weekly
# 2                                       Daily or almost daily
# 3                                      Multiple times per day
# 4                                       Daily or almost daily
# 5                                        A few times per week
# ...                                                       ...
# 83435                                                     NaN
# 83436       I have never participated in Q&A on Stack Over...
# 83437       I have never participated in Q&A on Stack Over...
# 83438                     Less than once per month or monthly
# 83439                                    A few times per week
#
#                      SOComm NEWOtherComms              Age Gender Trans  \
# ResponseId
# 1           Yes, definitely            No  25-34 years old    Man    No
# 2           Yes, definitely            No  18-24 years old    Man    No
# 3           Yes, definitely           Yes  18-24 years old    Man    No
# 4                   Neutral            No  35-44 years old    Man    No
# 5             Yes, somewhat            No  25-34 years old    Man    No
# ...                     ...           ...              ...    ...   ...
# 83435        No, not at all            No  25-34 years old    Man    No
# 83436         Yes, somewhat            No  18-24 years old    Man    No
# 83437        No, not really            No  25-34 years old    Man    No
# 83438        No, not really            No  25-34 years old    Man    No
# 83439         Yes, somewhat            No  18-24 years old    Man    No
#
#                           Sexuality                     Ethnicity  \
# ResponseId
# 1           Straight / Heterosexual  White or of European descent
# 2           Straight / Heterosexual  White or of European descent
# 3                 Prefer not to say             Prefer not to say
# 4           Straight / Heterosexual  White or of European descent
# 5                               NaN  White or of European descent
# ...                             ...                           ...
# 83435       Straight / Heterosexual  White or of European descent
# 83436       Straight / Heterosexual   Black or of African descent
# 83437                           NaN  White or of European descent
# 83438       Straight / Heterosexual  White or of European descent
# 83439       Straight / Heterosexual        Hispanic or Latino/a/x
#
#                           Accessibility  \
# ResponseId
# 1                     None of the above
# 2                     None of the above
# 3                     None of the above
# 4           I am deaf / hard of hearing
# 5                     None of the above
# ...                                 ...
# 83435                 None of the above
# 83436                 None of the above
# 83437                 None of the above
# 83438                 None of the above
# 83439                 None of the above
#
#                                                  MentalHealth  \
# ResponseId
# 1                                           None of the above
# 2                                           None of the above
# 3                                           None of the above
# 4                                                         NaN
# 5                                                         NaN
# ...                                                       ...
# 83435       I have a concentration and/or memory disorder ...
# 83436                                       None of the above
# 83437                                       None of the above
# 83438       I have a mood or emotional disorder (e.g. depr...
# 83439                                       None of the above
#
#                      SurveyLength                  SurveyEase  \
# ResponseId
# 1           Appropriate in length                        Easy
# 2           Appropriate in length                        Easy
# 3           Appropriate in length                        Easy
# 4           Appropriate in length  Neither easy nor difficult
# 5           Appropriate in length                        Easy
# ...                           ...                         ...
# 83435       Appropriate in length                        Easy
# 83436       Appropriate in length                        Easy
# 83437       Appropriate in length  Neither easy nor difficult
# 83438       Appropriate in length  Neither easy nor difficult
# 83439       Appropriate in length                        Easy
#
#             ConvertedCompYearly
# ResponseId
# 1                       62268.0
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# ...                         ...
# 83435                  160500.0
# 83436                    3960.0
# 83437                   90000.0
# 83438                  816816.0
# 83439                   21168.0
#
# [83439 rows x 47 columns]

# %%
countries = ['United States of America', 'India', 'United Kingdom of Great Britain and Northern Ireland', 'Germany', 'Canada']
filt = df['Country'].isin(countries)

# %%
df.loc[filt, 'Country']
# Out:
# ResponseId
# 5        United Kingdom of Great Britain and Northern I...
# 6                                 United States of America
# 7                                 United States of America
# 9                                                    India
# 11       United Kingdom of Great Britain and Northern I...
#                                ...
# 83431                             United States of America
# 83433                                               Canada
# 83435                             United States of America
# 83437                             United States of America
# 83438                                               Canada
# Name: Country, Length: 38911, dtype: object

# %%
filt2 = df['LanguageHaveWorkedWith'].str.contains('Python', na=False)

# %%
df.loc[filt2, 'LanguageHaveWorkedWith']
# Out:
# ResponseId
# 2                                        JavaScript;Python
# 3                                 Assembly;C;Python;R;Rust
# 5                           Bash/Shell;HTML/CSS;Python;SQL
# 6        C;C#;C++;HTML/CSS;Java;JavaScript;Node.js;Powe...
# 10                                              C++;Python
#                                ...
# 83430               HTML/CSS;PHP;PowerShell;Python;SQL;VBA
# 83431          APL;Clojure;LISP;Python;Ruby;SQL;TypeScript
# 83432    C#;Dart;HTML/CSS;Java;JavaScript;Kotlin;Node.j...
# 83437                                   Groovy;Java;Python
# 83438                 Bash/Shell;JavaScript;Node.js;Python
# Name: LanguageHaveWorkedWith, Length: 39792, dtype: object

# %%
df.rename(columns={'ConvertedCompYearly': 'SalaryUSD'}, inplace=True)
df['SalaryUSD']
# Out:
# ResponseId
# 1         62268.0
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
#            ...
# 83435    160500.0
# 83436      3960.0
# 83437     90000.0
# 83438    816816.0
# 83439     21168.0
# Name: SalaryUSD, Length: 83439, dtype: float64

# %%
df['NEWOtherComms']
# Out:
# ResponseId
# 1         No
# 2         No
# 3        Yes
# 4         No
# 5         No
#         ...
# 83435     No
# 83436     No
# 83437     No
# 83438     No
# 83439     No
# Name: NEWOtherComms, Length: 83439, dtype: object

# %%
df['NEWOtherComms'].map({'Yes': True, 'No': False})
# Out:
# ResponseId
# 1        False
# 2        False
# 3         True
# 4        False
# 5        False
#          ...
# 83435    False
# 83436    False
# 83437    False
# 83438    False
# 83439    False
# Name: NEWOtherComms, Length: 83439, dtype: object

# %%
df['NEWOtherComms'] = df['NEWOtherComms'].map({'Yes': True, 'No': False})
df.head()
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# 3                                          Student, full-time
# 4                                          Employed full-time
# 5           Independent contractor, freelancer, or self-em...
#
#                                                       Country US_State  \
# ResponseId
# 1                                                    Slovakia      NaN
# 2                                                 Netherlands      NaN
# 3                                          Russian Federation      NaN
# 4                                                     Austria      NaN
# 5           United Kingdom of Great Britain and Northern I...      NaN
#
#            UK_Country                                            EdLevel  \
# ResponseId
# 1                 NaN  Secondary school (e.g. American high school, G...
# 2                 NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3                 NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4                 NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5             England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                Age1stCode                                          LearnCode  \
# ResponseId
# 1           18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 2           11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3           11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 4           11 - 17 years                                                NaN
# 5            5 - 10 years                            Friend or family member
#
#            YearsCode YearsCodePro  \
# ResponseId
# 1                NaN          NaN
# 2                  7          NaN
# 3                NaN          NaN
# 4                NaN          NaN
# 5                 17           10
#
#                                                       DevType  \
# ResponseId
# 1                                           Developer, mobile
# 2                                                         NaN
# 3                                                         NaN
# 4                                        Developer, front-end
# 5           Developer, desktop or enterprise applications;...
#
#                                                       OrgSize  \
# ResponseId
# 1                                          20 to 99 employees
# 2                                                         NaN
# 3                                                         NaN
# 4                                        100 to 499 employees
# 5           Just me - I am a freelancer, sole proprietor, ...
#
#                        Currency  CompTotal CompFreq  \
# ResponseId
# 1             EUR European Euro     4800.0  Monthly
# 2                           NaN        NaN      NaN
# 3                           NaN        NaN      NaN
# 4             EUR European Euro        NaN  Monthly
# 5           GBP\tPound sterling        NaN      NaN
#
#                                    LanguageHaveWorkedWith  \
# ResponseId
# 1           C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 2                                       JavaScript;Python
# 3                                Assembly;C;Python;R;Rust
# 4                                   JavaScript;TypeScript
# 5                          Bash/Shell;HTML/CSS;Python;SQL
#
#                     LanguageWantToWorkWith          DatabaseHaveWorkedWith  \
# ResponseId
# 1                                    Swift               PostgreSQL;SQLite
# 2                                      NaN                      PostgreSQL
# 3                        Julia;Python;Rust                          SQLite
# 4                    JavaScript;TypeScript                             NaN
# 5           Bash/Shell;HTML/CSS;Python;SQL  Elasticsearch;PostgreSQL;Redis
#
#                               DatabaseWantToWorkWith PlatformHaveWorkedWith  \
# ResponseId
# 1                                             SQLite                    NaN
# 2                                                NaN                    NaN
# 3                                             SQLite                 Heroku
# 4                                                NaN                    NaN
# 5           Cassandra;Elasticsearch;PostgreSQL;Redis                    NaN
#
#            PlatformWantToWorkWith WebframeHaveWorkedWith  \
# ResponseId
# 1                             NaN        Laravel;Symfony
# 2                             NaN   Angular;Flask;Vue.js
# 3                             NaN                  Flask
# 4                             NaN         Angular;jQuery
# 5                             NaN                  Flask
#
#            WebframeWantToWorkWith                 MiscTechHaveWorkedWith  \
# ResponseId
# 1                             NaN                                    NaN
# 2                             NaN                                Cordova
# 3                           Flask  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 4                  Angular;jQuery                                    NaN
# 5                           Flask       Apache Spark;Hadoop;NumPy;Pandas
#
#                                  MiscTechWantToWorkWith  \
# ResponseId
# 1                                                   NaN
# 2                                                   NaN
# 3           Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 4                                                   NaN
# 5                                   Hadoop;NumPy;Pandas
#
#                ToolsTechHaveWorkedWith     ToolsTechWantToWorkWith  \
# ResponseId
# 1                                  NaN                         NaN
# 2                      Docker;Git;Yarn                         Git
# 3                                  NaN                         NaN
# 4                                  NaN                         NaN
# 5           Docker;Git;Kubernetes;Yarn  Docker;Git;Kubernetes;Yarn
#
#                                  NEWCollabToolsHaveWorkedWith  \
# ResponseId
# 1                                              PHPStorm;Xcode
# 2                   Android Studio;IntelliJ;Notepad++;PyCharm
# 3           IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 4                                                         NaN
# 5                  Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
#
#                                  NEWCollabToolsWantToWorkWith        OpSys  \
# ResponseId
# 1                                                  Atom;Xcode        MacOS
# 2                                                         NaN      Windows
# 3           IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 4                                                         NaN      Windows
# 5           Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
#
#                                                      NEWStuck  \
# ResponseId
# 1           Call a coworker or friend;Visit Stack Overflow...
# 2                              Visit Stack Overflow;Google it
# 3           Visit Stack Overflow;Google it;Watch help / tu...
# 4           Call a coworker or friend;Visit Stack Overflow...
# 5           Visit Stack Overflow;Go for a walk or other ph...
#
#                                NEWSOSites             SOVisitFreq SOAccount  \
# ResponseId
# 1                          Stack Overflow  Multiple times per day       Yes
# 2                          Stack Overflow   Daily or almost daily       Yes
# 3           Stack Overflow;Stack Exchange  Multiple times per day       Yes
# 4                          Stack Overflow   Daily or almost daily       Yes
# 5           Stack Overflow;Stack Exchange   Daily or almost daily       Yes
#
#                                  SOPartFreq           SOComm NEWOtherComms  \
# ResponseId
# 1           A few times per month or weekly  Yes, definitely         False
# 2                     Daily or almost daily  Yes, definitely         False
# 3                    Multiple times per day  Yes, definitely          True
# 4                     Daily or almost daily          Neutral         False
# 5                      A few times per week    Yes, somewhat         False
#
#                         Age Gender Trans                Sexuality  \
# ResponseId
# 1           25-34 years old    Man    No  Straight / Heterosexual
# 2           18-24 years old    Man    No  Straight / Heterosexual
# 3           18-24 years old    Man    No        Prefer not to say
# 4           35-44 years old    Man    No  Straight / Heterosexual
# 5           25-34 years old    Man    No                      NaN
#
#                                Ethnicity                Accessibility  \
# ResponseId
# 1           White or of European descent            None of the above
# 2           White or of European descent            None of the above
# 3                      Prefer not to say            None of the above
# 4           White or of European descent  I am deaf / hard of hearing
# 5           White or of European descent            None of the above
#
#                  MentalHealth           SurveyLength  \
# ResponseId
# 1           None of the above  Appropriate in length
# 2           None of the above  Appropriate in length
# 3           None of the above  Appropriate in length
# 4                         NaN  Appropriate in length
# 5                         NaN  Appropriate in length
#
#                             SurveyEase  SalaryUSD
# ResponseId
# 1                                 Easy    62268.0
# 2                                 Easy        NaN
# 3                                 Easy        NaN
# 4           Neither easy nor difficult        NaN
# 5                                 Easy        NaN

# %%
import pandas as pd
df = pd.read_csv('data/survey_results_public.csv', index_col='ResponseId')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='qname')
pd.set_option('display.max_columns', 48)
pd.set_option('display.max_rows', 48)

# %%
df.head()
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# 3                                          Student, full-time
# 4                                          Employed full-time
# 5           Independent contractor, freelancer, or self-em...
#
#                                                       Country US_State  \
# ResponseId
# 1                                                    Slovakia      NaN
# 2                                                 Netherlands      NaN
# 3                                          Russian Federation      NaN
# 4                                                     Austria      NaN
# 5           United Kingdom of Great Britain and Northern I...      NaN
#
#            UK_Country                                            EdLevel  \
# ResponseId
# 1                 NaN  Secondary school (e.g. American high school, G...
# 2                 NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3                 NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4                 NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5             England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                Age1stCode                                          LearnCode  \
# ResponseId
# 1           18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 2           11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3           11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 4           11 - 17 years                                                NaN
# 5            5 - 10 years                            Friend or family member
#
#            YearsCode YearsCodePro  \
# ResponseId
# 1                NaN          NaN
# 2                  7          NaN
# 3                NaN          NaN
# 4                NaN          NaN
# 5                 17           10
#
#                                                       DevType  \
# ResponseId
# 1                                           Developer, mobile
# 2                                                         NaN
# 3                                                         NaN
# 4                                        Developer, front-end
# 5           Developer, desktop or enterprise applications;...
#
#                                                       OrgSize  \
# ResponseId
# 1                                          20 to 99 employees
# 2                                                         NaN
# 3                                                         NaN
# 4                                        100 to 499 employees
# 5           Just me - I am a freelancer, sole proprietor, ...
#
#                        Currency  CompTotal CompFreq  \
# ResponseId
# 1             EUR European Euro     4800.0  Monthly
# 2                           NaN        NaN      NaN
# 3                           NaN        NaN      NaN
# 4             EUR European Euro        NaN  Monthly
# 5           GBP\tPound sterling        NaN      NaN
#
#                                    LanguageHaveWorkedWith  \
# ResponseId
# 1           C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 2                                       JavaScript;Python
# 3                                Assembly;C;Python;R;Rust
# 4                                   JavaScript;TypeScript
# 5                          Bash/Shell;HTML/CSS;Python;SQL
#
#                     LanguageWantToWorkWith          DatabaseHaveWorkedWith  \
# ResponseId
# 1                                    Swift               PostgreSQL;SQLite
# 2                                      NaN                      PostgreSQL
# 3                        Julia;Python;Rust                          SQLite
# 4                    JavaScript;TypeScript                             NaN
# 5           Bash/Shell;HTML/CSS;Python;SQL  Elasticsearch;PostgreSQL;Redis
#
#                               DatabaseWantToWorkWith PlatformHaveWorkedWith  \
# ResponseId
# 1                                             SQLite                    NaN
# 2                                                NaN                    NaN
# 3                                             SQLite                 Heroku
# 4                                                NaN                    NaN
# 5           Cassandra;Elasticsearch;PostgreSQL;Redis                    NaN
#
#            PlatformWantToWorkWith WebframeHaveWorkedWith  \
# ResponseId
# 1                             NaN        Laravel;Symfony
# 2                             NaN   Angular;Flask;Vue.js
# 3                             NaN                  Flask
# 4                             NaN         Angular;jQuery
# 5                             NaN                  Flask
#
#            WebframeWantToWorkWith                 MiscTechHaveWorkedWith  \
# ResponseId
# 1                             NaN                                    NaN
# 2                             NaN                                Cordova
# 3                           Flask  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 4                  Angular;jQuery                                    NaN
# 5                           Flask       Apache Spark;Hadoop;NumPy;Pandas
#
#                                  MiscTechWantToWorkWith  \
# ResponseId
# 1                                                   NaN
# 2                                                   NaN
# 3           Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 4                                                   NaN
# 5                                   Hadoop;NumPy;Pandas
#
#                ToolsTechHaveWorkedWith     ToolsTechWantToWorkWith  \
# ResponseId
# 1                                  NaN                         NaN
# 2                      Docker;Git;Yarn                         Git
# 3                                  NaN                         NaN
# 4                                  NaN                         NaN
# 5           Docker;Git;Kubernetes;Yarn  Docker;Git;Kubernetes;Yarn
#
#                                  NEWCollabToolsHaveWorkedWith  \
# ResponseId
# 1                                              PHPStorm;Xcode
# 2                   Android Studio;IntelliJ;Notepad++;PyCharm
# 3           IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 4                                                         NaN
# 5                  Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
#
#                                  NEWCollabToolsWantToWorkWith        OpSys  \
# ResponseId
# 1                                                  Atom;Xcode        MacOS
# 2                                                         NaN      Windows
# 3           IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 4                                                         NaN      Windows
# 5           Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
#
#                                                      NEWStuck  \
# ResponseId
# 1           Call a coworker or friend;Visit Stack Overflow...
# 2                              Visit Stack Overflow;Google it
# 3           Visit Stack Overflow;Google it;Watch help / tu...
# 4           Call a coworker or friend;Visit Stack Overflow...
# 5           Visit Stack Overflow;Go for a walk or other ph...
#
#                                NEWSOSites             SOVisitFreq SOAccount  \
# ResponseId
# 1                          Stack Overflow  Multiple times per day       Yes
# 2                          Stack Overflow   Daily or almost daily       Yes
# 3           Stack Overflow;Stack Exchange  Multiple times per day       Yes
# 4                          Stack Overflow   Daily or almost daily       Yes
# 5           Stack Overflow;Stack Exchange   Daily or almost daily       Yes
#
#                                  SOPartFreq           SOComm NEWOtherComms  \
# ResponseId
# 1           A few times per month or weekly  Yes, definitely            No
# 2                     Daily or almost daily  Yes, definitely            No
# 3                    Multiple times per day  Yes, definitely           Yes
# 4                     Daily or almost daily          Neutral            No
# 5                      A few times per week    Yes, somewhat            No
#
#                         Age Gender Trans                Sexuality  \
# ResponseId
# 1           25-34 years old    Man    No  Straight / Heterosexual
# 2           18-24 years old    Man    No  Straight / Heterosexual
# 3           18-24 years old    Man    No        Prefer not to say
# 4           35-44 years old    Man    No  Straight / Heterosexual
# 5           25-34 years old    Man    No                      NaN
#
#                                Ethnicity                Accessibility  \
# ResponseId
# 1           White or of European descent            None of the above
# 2           White or of European descent            None of the above
# 3                      Prefer not to say            None of the above
# 4           White or of European descent  I am deaf / hard of hearing
# 5           White or of European descent            None of the above
#
#                  MentalHealth           SurveyLength  \
# ResponseId
# 1           None of the above  Appropriate in length
# 2           None of the above  Appropriate in length
# 3           None of the above  Appropriate in length
# 4                         NaN  Appropriate in length
# 5                         NaN  Appropriate in length
#
#                             SurveyEase  ConvertedCompYearly
# ResponseId
# 1                                 Easy              62268.0
# 2                                 Easy                  NaN
# 3                                 Easy                  NaN
# 4           Neither easy nor difficult                  NaN
# 5                                 Easy                  NaN

# %%
df.sort_values(by=['Country', 'ConvertedCompYearly'], ascending=[True, False], inplace=True)

# %%
df[['Country', 'ConvertedCompYearly']].head(48)
# Out:
#                 Country  ConvertedCompYearly
# ResponseId
# 65400       Afghanistan           30468516.0
# 22667       Afghanistan             155496.0
# 27199       Afghanistan              51804.0
# 31087       Afghanistan              23964.0
# 44641       Afghanistan              15132.0
# 11378       Afghanistan               9792.0
# 17487       Afghanistan               5448.0
# 51429       Afghanistan               4668.0
# 14883       Afghanistan               4200.0
# 17121       Afghanistan               3108.0
# 55151       Afghanistan                100.0
# 2070        Afghanistan                  NaN
# 4545        Afghanistan                  NaN
# 5101        Afghanistan                  NaN
# 9565        Afghanistan                  NaN
# 10946       Afghanistan                  NaN
# 11132       Afghanistan                  NaN
# 11462       Afghanistan                  NaN
# 20302       Afghanistan                  NaN
# 23457       Afghanistan                  NaN
# 24553       Afghanistan                  NaN
# 26035       Afghanistan                  NaN
# 26956       Afghanistan                  NaN
# 28379       Afghanistan                  NaN
# 30553       Afghanistan                  NaN
# 31505       Afghanistan                  NaN
# 31597       Afghanistan                  NaN
# 31891       Afghanistan                  NaN
# 34428       Afghanistan                  NaN
# 37432       Afghanistan                  NaN
# 37550       Afghanistan                  NaN
# 37766       Afghanistan                  NaN
# 38694       Afghanistan                  NaN
# 39472       Afghanistan                  NaN
# 40224       Afghanistan                  NaN
# 40403       Afghanistan                  NaN
# 41841       Afghanistan                  NaN
# 46340       Afghanistan                  NaN
# 51792       Afghanistan                  NaN
# 53204       Afghanistan                  NaN
# 55625       Afghanistan                  NaN
# 59269       Afghanistan                  NaN
# 61675       Afghanistan                  NaN
# 62113       Afghanistan                  NaN
# 62691       Afghanistan                  NaN
# 62787       Afghanistan                  NaN
# 62833       Afghanistan                  NaN
# 62971       Afghanistan                  NaN

# %%
df['ConvertedCompYearly'].nlargest(10)
# Out:
# ResponseId
# 66911    45241312.0
# 65400    30468516.0
# 40587    21822250.0
# 28792    20000000.0
# 12701    19200000.0
# 9609     17500000.0
# 5306     15000000.0
# 12904    14411628.0
# 66489    12750000.0
# 7206     12500000.0
# Name: ConvertedCompYearly, dtype: float64

# %%
df.nsmallest(10, 'ConvertedCompYearly')
# Out:
#                                                    MainBranch  \
# ResponseId
# 1925                           I am a developer by profession
# 24286                          I am a developer by profession
# 46465       I am not primarily a developer, but I write co...
# 15164                          I am a developer by profession
# 56791                          I am a developer by profession
# 22033                          I am a developer by profession
# 59044                          I am a developer by profession
# 22454                          I am a developer by profession
# 45142       I am not primarily a developer, but I write co...
# 53307                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1925                                       Employed full-time
# 24286       Independent contractor, freelancer, or self-em...
# 46465                                      Employed full-time
# 15164                                      Employed full-time
# 56791                                      Employed full-time
# 22033                                      Employed full-time
# 59044                                      Employed full-time
# 22454                                      Employed full-time
# 45142                                      Employed full-time
# 53307                                      Employed full-time
#
#                              Country      US_State UK_Country  \
# ResponseId
# 1925        United States of America  Pennsylvania        NaN
# 24286       United States of America    California        NaN
# 46465       United States of America    Washington        NaN
# 15164                          China           NaN        NaN
# 56791                         Taiwan           NaN        NaN
# 22033              Republic of Korea           NaN        NaN
# 59044                         Taiwan           NaN        NaN
# 22454                          Japan           NaN        NaN
# 45142                          China           NaN        NaN
# 53307                          Japan           NaN        NaN
#
#                                                       EdLevel  \
# ResponseId
# 1925          Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 24286            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 46465            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 15164                               Primary/elementary school
# 56791         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 22033                     Associate degree (A.A., A.S., etc.)
# 59044         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 22454       Secondary school (e.g. American high school, G...
# 45142         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 53307       Some college/university study without earning ...
#
#                       Age1stCode  \
# ResponseId
# 1925               11 - 17 years
# 24286              11 - 17 years
# 46465              11 - 17 years
# 15164       Younger than 5 years
# 56791              11 - 17 years
# 22033              18 - 24 years
# 59044              18 - 24 years
# 22454               5 - 10 years
# 45142              11 - 17 years
# 53307              11 - 17 years
#
#                                                     LearnCode  \
# ResponseId
# 1925                           School;Other (please specify):
# 24286                                  Books / Physical media
# 46465       Coding Bootcamp;Other online resources (ex: vi...
# 15164                                  Books / Physical media
# 56791                                                  School
# 22033       Coding Bootcamp;Other online resources (ex: vi...
# 59044       Other online resources (ex: videos, blogs, etc...
# 22454         Other online resources (ex: videos, blogs, etc)
# 45142       Other online resources (ex: videos, blogs, etc...
# 53307       Other online resources (ex: videos, blogs, etc...
#
#                    YearsCode      YearsCodePro  \
# ResponseId
# 1925                      30                25
# 24286                     16                 9
# 46465                     27                12
# 15164                      5                 1
# 56791                     12                 2
# 22033                      5  Less than 1 year
# 59044                     20               NaN
# 22454       Less than 1 year                 6
# 45142                     12                 1
# 53307                     25                17
#
#                                                       DevType  \
# ResponseId
# 1925        Developer, mobile;Developer, front-end;Develop...
# 24286       Other (please specify):;Data scientist or mach...
# 46465       Engineer, data;Data scientist or machine learn...
# 15164                                     Academic researcher
# 56791       Developer, full-stack;Database administrator;S...
# 22033                                    Developer, front-end
# 59044                                    Developer, front-end
# 22454                                   Developer, full-stack
# 45142                                               Scientist
# 53307       Developer, mobile;Data scientist or machine le...
#
#                              OrgSize                    Currency  CompTotal  \
# ResponseId
# 1925        1,000 to 4,999 employees   USD\tUnited States dollar        1.0
# 24286               2 to 9 employees   USD\tUnited States dollar        1.0
# 46465             10 to 19 employees   USD\tUnited States dollar        1.0
# 15164               2 to 9 employees  CNY\tChinese Yuan Renminbi       11.0
# 56791           100 to 499 employees      TWD\tNew Taiwan dollar       50.0
# 22033             20 to 99 employees       KRW\tSouth Korean won     3800.0
# 59044           100 to 499 employees      TWD\tNew Taiwan dollar       90.0
# 22454             20 to 99 employees           JPY\tJapanese yen      450.0
# 45142       1,000 to 4,999 employees  CNY\tChinese Yuan Renminbi       35.0
# 53307       10,000 or more employees           JPY\tJapanese yen      600.0
#
#            CompFreq                             LanguageHaveWorkedWith  \
# ResponseId
# 1925         Yearly              C#;HTML/CSS;JavaScript;PowerShell;SQL
# 24286        Yearly                                         Python;SQL
# 46465        Yearly                                        Perl;Python
# 15164        Yearly                                        Objective-C
# 56791        Yearly             HTML/CSS;JavaScript;Node.js;Python;SQL
# 22033        Yearly                              JavaScript;TypeScript
# 59044        Yearly  HTML/CSS;JavaScript;Node.js;PowerShell;TypeScript
# 22454        Yearly                         C#;HTML/CSS;SQL;TypeScript
# 45142        Yearly                        C++;Java;Python;R;Scala;SQL
# 53307        Yearly  Bash/Shell;HTML/CSS;Java;JavaScript;Kotlin;Nod...
#
#                                        LanguageWantToWorkWith  \
# ResponseId
# 1925                    C#;HTML/CSS;JavaScript;PowerShell;SQL
# 24286                                                  Python
# 46465                               JavaScript;Node.js;Python
# 15164                                                     NaN
# 56791                                                     NaN
# 22033                                   JavaScript;TypeScript
# 59044                  HTML/CSS;JavaScript;Node.js;TypeScript
# 22454                              C#;HTML/CSS;SQL;TypeScript
# 45142                                              C++;Python
# 53307       Bash/Shell;C#;HTML/CSS;Java;Kotlin;Python;SQL;...
#
#                                 DatabaseHaveWorkedWith  \
# ResponseId
# 1925                              Microsoft SQL Server
# 24286                                 PostgreSQL;Redis
# 46465                                           SQLite
# 15164                                            MySQL
# 56791                          MySQL;PostgreSQL;SQLite
# 22033                           MySQL;PostgreSQL;Redis
# 59044       Elasticsearch;Firebase;MongoDB;MySQL;Redis
# 22454                                           Oracle
# 45142                                              NaN
# 53307                 Firebase;MySQL;PostgreSQL;SQLite
#
#                DatabaseWantToWorkWith        PlatformHaveWorkedWith  \
# ResponseId
# 1925             Microsoft SQL Server           AWS;Microsoft Azure
# 24286                PostgreSQL;Redis                           AWS
# 46465                             NaN         Google Cloud Platform
# 15164                             NaN               Microsoft Azure
# 56791                             NaN                           NaN
# 22033          MySQL;PostgreSQL;Redis     AWS;Google Cloud Platform
# 59044                        Firebase  DigitalOcean;Microsoft Azure
# 22454                          Oracle           AWS;Microsoft Azure
# 45142                             NaN                           NaN
# 53307       MariaDB;PostgreSQL;SQLite                           AWS
#
#                PlatformWantToWorkWith  \
# ResponseId
# 1925                              NaN
# 24286                             AWS
# 46465                             NaN
# 15164                             NaN
# 56791                             NaN
# 22033       AWS;Google Cloud Platform
# 59044                             NaN
# 22454             AWS;Microsoft Azure
# 45142                             NaN
# 53307                             AWS
#
#                                      WebframeHaveWorkedWith  \
# ResponseId
# 1925        Angular;Angular.js;ASP.NET;ASP.NET Core ;jQuery
# 24286                                          Django;Flask
# 46465                                                 Flask
# 15164                                                Vue.js
# 56791                                         Django;jQuery
# 22033                                              React.js
# 59044                                       Angular;Express
# 22454                                 Angular;ASP.NET Core
# 45142                                                   NaN
# 53307           Angular;Express;Flask;Laravel;Spring;Vue.js
#
#                                      WebframeWantToWorkWith  \
# ResponseId
# 1925        Angular;Angular.js;ASP.NET;ASP.NET Core ;jQuery
# 24286                                          Django;Flask
# 46465                                                 Flask
# 15164                                                   NaN
# 56791                                                   NaN
# 22033                                React.js;Svelte;Vue.js
# 59044                                               Angular
# 22454                                 Angular;ASP.NET Core
# 45142                                                   NaN
# 53307                 Angular;ASP.NET Core ;FastAPI;Laravel
#
#                                  MiscTechHaveWorkedWith  \
# ResponseId
# 1925                  .NET Framework;.NET Core / .NET 5
# 24286                           NumPy;Pandas;TensorFlow
# 46465                                           Flutter
# 15164                                               NaN
# 56791                                               NaN
# 22033                               Hadoop;React Native
# 59044                                               NaN
# 22454                                .NET Core / .NET 5
# 45142                 Hadoop;NumPy;Pandas;Torch/PyTorch
# 53307       Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
#
#                                    MiscTechWantToWorkWith  \
# ResponseId
# 1925                    .NET Framework;.NET Core / .NET 5
# 24286                             NumPy;Pandas;TensorFlow
# 46465                                                 NaN
# 15164                                                 NaN
# 56791                                                 NaN
# 22033                         Flutter;Hadoop;React Native
# 59044                                                 NaN
# 22454                                  .NET Core / .NET 5
# 45142                          NumPy;Pandas;Torch/PyTorch
# 53307       .NET Core / .NET 5;NumPy;Pandas;Torch/PyTorch
#
#                ToolsTechHaveWorkedWith          ToolsTechWantToWorkWith  \
# ResponseId
# 1925             Docker;Git;Kubernetes            Docker;Git;Kubernetes
# 24286             Docker;Git;Terraform             Docker;Git;Terraform
# 46465                              Git                              Git
# 15164                              NaN                              NaN
# 56791                       Docker;Git                              NaN
# 22033       Docker;Git;Kubernetes;Yarn  Deno;Docker;Git;Kubernetes;Yarn
# 59044               Ansible;Docker;Git                       Docker;Git
# 22454                              NaN                              NaN
# 45142                              Git                              Git
# 53307                       Docker;Git       Git;Unity 3D;Unreal Engine
#
#                                  NEWCollabToolsHaveWorkedWith  \
# ResponseId
# 1925               Notepad++;Visual Studio;Visual Studio Code
# 24286                                 IPython/Jupyter;PyCharm
# 46465            Android Studio;IntelliJ;PyCharm;Sublime Text
# 15164                                                     NaN
# 56791                                                 PyCharm
# 22033                             Visual Studio Code;Webstorm
# 59044       IntelliJ;Notepad++;Vim;Visual Studio Code;Webs...
# 22454                        Visual Studio;Visual Studio Code
# 45142       IntelliJ;PyCharm;RStudio;Visual Studio;Visual ...
# 53307       Android Studio;IntelliJ;IPython/Jupyter;PHPSto...
#
#                                  NEWCollabToolsWantToWorkWith        OpSys  \
# ResponseId
# 1925               Notepad++;Visual Studio;Visual Studio Code      Windows
# 24286                                 IPython/Jupyter;PyCharm        MacOS
# 46465                                    PyCharm;Sublime Text        MacOS
# 15164                                                     NaN        MacOS
# 56791                                                     NaN      Windows
# 22033                             Visual Studio Code;Webstorm        MacOS
# 59044       IntelliJ;Notepad++;Vim;Visual Studio Code;Webs...        MacOS
# 22454                        Visual Studio;Visual Studio Code      Windows
# 45142                                      Visual Studio Code      Windows
# 53307       Android Studio;IntelliJ;PHPStorm;PyCharm;Vim;V...  Linux-based
#
#                                                      NEWStuck  \
# ResponseId
# 1925        Call a coworker or friend;Visit Stack Overflow...
# 24286       Visit Stack Overflow;Go for a walk or other ph...
# 46465       Go for a walk or other physical activity;Do ot...
# 15164                                               Google it
# 56791       Call a coworker or friend;Visit Stack Overflow...
# 22033       Visit Stack Overflow;Go for a walk or other ph...
# 59044       Go for a walk or other physical activity;Googl...
# 22454                      Call a coworker or friend;Meditate
# 45142       Visit Stack Overflow;Google it;Do other work a...
# 53307       Visit Stack Overflow;Google it;Watch help / tu...
#
#                                                    NEWSOSites  \
# ResponseId
# 1925                            Stack Overflow;Stack Exchange
# 24286                           Stack Overflow;Stack Exchange
# 46465                                          Stack Overflow
# 15164       Stack Overflow for Teams (private knowledge sh...
# 56791                                          Stack Overflow
# 22033                                          Stack Overflow
# 59044                                          Stack Overflow
# 22454                                          Stack Overflow
# 45142                           Stack Overflow;Stack Exchange
# 53307                           Stack Overflow;Stack Exchange
#
#                                     SOVisitFreq                SOAccount  \
# ResponseId
# 1925                       A few times per week                      Yes
# 24286                      A few times per week                      Yes
# 46465       Less than once per month or monthly                       No
# 15164       Less than once per month or monthly                      Yes
# 56791                     Daily or almost daily                      Yes
# 22033                     Daily or almost daily                      Yes
# 59044                    Multiple times per day                      Yes
# 22454           A few times per month or weekly  Not sure/can't remember
# 45142                     Daily or almost daily                      Yes
# 53307                     Daily or almost daily                       No
#
#                                                    SOPartFreq  \
# ResponseId
# 1925                                     A few times per week
# 24286                                    A few times per week
# 46465                                                     NaN
# 15164       I have never participated in Q&A on Stack Over...
# 56791                     Less than once per month or monthly
# 22033                     Less than once per month or monthly
# 59044       I have never participated in Q&A on Stack Over...
# 22454                                                     NaN
# 45142                         A few times per month or weekly
# 53307                                                     NaN
#
#                      SOComm NEWOtherComms              Age Gender  \
# ResponseId
# 1925        Yes, definitely            No  45-54 years old    Man
# 24286         Yes, somewhat           Yes  35-44 years old    Man
# 46465        No, not at all            No  35-44 years old    Man
# 15164        No, not at all           Yes  35-44 years old  Woman
# 56791        No, not really            No  25-34 years old  Woman
# 22033         Yes, somewhat            No  25-34 years old    Man
# 59044         Yes, somewhat            No  25-34 years old    Man
# 22454        No, not at all            No  35-44 years old    Man
# 45142         Yes, somewhat           Yes  18-24 years old    Man
# 53307               Neutral            No  35-44 years old    Man
#
#                         Trans                 Sexuality  \
# ResponseId
# 1925                       No                       NaN
# 24286                      No  Prefer to self-describe:
# 46465       Prefer not to say         Prefer not to say
# 15164                     Yes                  Bisexual
# 56791                      No   Straight / Heterosexual
# 22033                      No                       NaN
# 59044                      No         Prefer not to say
# 22454                      No                       NaN
# 45142                      No   Straight / Heterosexual
# 53307                      No   Straight / Heterosexual
#
#                                Ethnicity                        Accessibility  \
# ResponseId
# 1925        White or of European descent                    None of the above
# 24286       White or of European descent                    None of the above
# 46465                  Prefer not to say                    Prefer not to say
# 15164        Black or of African descent  I am blind / have difficulty seeing
# 56791                         East Asian                    None of the above
# 22033                         East Asian                    None of the above
# 59044                    Southeast Asian                    None of the above
# 22454                         East Asian                    None of the above
# 45142                         East Asian                    None of the above
# 53307                         East Asian                    None of the above
#
#                                                  MentalHealth  \
# ResponseId
# 1925                                        None of the above
# 24286                                       None of the above
# 46465                                       Prefer not to say
# 15164       I have a concentration and/or memory disorder ...
# 56791                                       None of the above
# 22033                              I have an anxiety disorder
# 59044                                       None of the above
# 22454                                                     NaN
# 45142       I have a mood or emotional disorder (e.g. depr...
# 53307                                       None of the above
#
#                      SurveyLength                  SurveyEase  \
# ResponseId
# 1925                     Too long  Neither easy nor difficult
# 24286       Appropriate in length                        Easy
# 46465                    Too long                        Easy
# 15164                   Too short                        Easy
# 56791       Appropriate in length                        Easy
# 22033       Appropriate in length                        Easy
# 59044       Appropriate in length                        Easy
# 22454       Appropriate in length                        Easy
# 45142                    Too long                        Easy
# 53307       Appropriate in length                        Easy
#
#             ConvertedCompYearly
# ResponseId
# 1925                        1.0
# 24286                       1.0
# 46465                       1.0
# 15164                       2.0
# 56791                       2.0
# 22033                       3.0
# 59044                       3.0
# 22454                       4.0
# 45142                       5.0
# 53307                       5.0

# %%
df.loc[66911, 'OrgSize']
# Out:
# 'Just me - I am a freelancer, sole proprietor, etc.'

# %%
import pandas as pd
df = pd.read_csv('data/survey_results_public.csv', index_col='ResponseId')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='qname')
pd.set_option('display.max_columns', 48)
pd.set_option('display.max_rows', 48)

# %%
df.head()
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# 3                                          Student, full-time
# 4                                          Employed full-time
# 5           Independent contractor, freelancer, or self-em...
#
#                                                       Country US_State  \
# ResponseId
# 1                                                    Slovakia      NaN
# 2                                                 Netherlands      NaN
# 3                                          Russian Federation      NaN
# 4                                                     Austria      NaN
# 5           United Kingdom of Great Britain and Northern I...      NaN
#
#            UK_Country                                            EdLevel  \
# ResponseId
# 1                 NaN  Secondary school (e.g. American high school, G...
# 2                 NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3                 NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4                 NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5             England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                Age1stCode                                          LearnCode  \
# ResponseId
# 1           18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 2           11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3           11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 4           11 - 17 years                                                NaN
# 5            5 - 10 years                            Friend or family member
#
#            YearsCode YearsCodePro  \
# ResponseId
# 1                NaN          NaN
# 2                  7          NaN
# 3                NaN          NaN
# 4                NaN          NaN
# 5                 17           10
#
#                                                       DevType  \
# ResponseId
# 1                                           Developer, mobile
# 2                                                         NaN
# 3                                                         NaN
# 4                                        Developer, front-end
# 5           Developer, desktop or enterprise applications;...
#
#                                                       OrgSize  \
# ResponseId
# 1                                          20 to 99 employees
# 2                                                         NaN
# 3                                                         NaN
# 4                                        100 to 499 employees
# 5           Just me - I am a freelancer, sole proprietor, ...
#
#                        Currency  CompTotal CompFreq  \
# ResponseId
# 1             EUR European Euro     4800.0  Monthly
# 2                           NaN        NaN      NaN
# 3                           NaN        NaN      NaN
# 4             EUR European Euro        NaN  Monthly
# 5           GBP\tPound sterling        NaN      NaN
#
#                                    LanguageHaveWorkedWith  \
# ResponseId
# 1           C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 2                                       JavaScript;Python
# 3                                Assembly;C;Python;R;Rust
# 4                                   JavaScript;TypeScript
# 5                          Bash/Shell;HTML/CSS;Python;SQL
#
#                     LanguageWantToWorkWith          DatabaseHaveWorkedWith  \
# ResponseId
# 1                                    Swift               PostgreSQL;SQLite
# 2                                      NaN                      PostgreSQL
# 3                        Julia;Python;Rust                          SQLite
# 4                    JavaScript;TypeScript                             NaN
# 5           Bash/Shell;HTML/CSS;Python;SQL  Elasticsearch;PostgreSQL;Redis
#
#                               DatabaseWantToWorkWith PlatformHaveWorkedWith  \
# ResponseId
# 1                                             SQLite                    NaN
# 2                                                NaN                    NaN
# 3                                             SQLite                 Heroku
# 4                                                NaN                    NaN
# 5           Cassandra;Elasticsearch;PostgreSQL;Redis                    NaN
#
#            PlatformWantToWorkWith WebframeHaveWorkedWith  \
# ResponseId
# 1                             NaN        Laravel;Symfony
# 2                             NaN   Angular;Flask;Vue.js
# 3                             NaN                  Flask
# 4                             NaN         Angular;jQuery
# 5                             NaN                  Flask
#
#            WebframeWantToWorkWith                 MiscTechHaveWorkedWith  \
# ResponseId
# 1                             NaN                                    NaN
# 2                             NaN                                Cordova
# 3                           Flask  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 4                  Angular;jQuery                                    NaN
# 5                           Flask       Apache Spark;Hadoop;NumPy;Pandas
#
#                                  MiscTechWantToWorkWith  \
# ResponseId
# 1                                                   NaN
# 2                                                   NaN
# 3           Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 4                                                   NaN
# 5                                   Hadoop;NumPy;Pandas
#
#                ToolsTechHaveWorkedWith     ToolsTechWantToWorkWith  \
# ResponseId
# 1                                  NaN                         NaN
# 2                      Docker;Git;Yarn                         Git
# 3                                  NaN                         NaN
# 4                                  NaN                         NaN
# 5           Docker;Git;Kubernetes;Yarn  Docker;Git;Kubernetes;Yarn
#
#                                  NEWCollabToolsHaveWorkedWith  \
# ResponseId
# 1                                              PHPStorm;Xcode
# 2                   Android Studio;IntelliJ;Notepad++;PyCharm
# 3           IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 4                                                         NaN
# 5                  Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
#
#                                  NEWCollabToolsWantToWorkWith        OpSys  \
# ResponseId
# 1                                                  Atom;Xcode        MacOS
# 2                                                         NaN      Windows
# 3           IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 4                                                         NaN      Windows
# 5           Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
#
#                                                      NEWStuck  \
# ResponseId
# 1           Call a coworker or friend;Visit Stack Overflow...
# 2                              Visit Stack Overflow;Google it
# 3           Visit Stack Overflow;Google it;Watch help / tu...
# 4           Call a coworker or friend;Visit Stack Overflow...
# 5           Visit Stack Overflow;Go for a walk or other ph...
#
#                                NEWSOSites             SOVisitFreq SOAccount  \
# ResponseId
# 1                          Stack Overflow  Multiple times per day       Yes
# 2                          Stack Overflow   Daily or almost daily       Yes
# 3           Stack Overflow;Stack Exchange  Multiple times per day       Yes
# 4                          Stack Overflow   Daily or almost daily       Yes
# 5           Stack Overflow;Stack Exchange   Daily or almost daily       Yes
#
#                                  SOPartFreq           SOComm NEWOtherComms  \
# ResponseId
# 1           A few times per month or weekly  Yes, definitely            No
# 2                     Daily or almost daily  Yes, definitely            No
# 3                    Multiple times per day  Yes, definitely           Yes
# 4                     Daily or almost daily          Neutral            No
# 5                      A few times per week    Yes, somewhat            No
#
#                         Age Gender Trans                Sexuality  \
# ResponseId
# 1           25-34 years old    Man    No  Straight / Heterosexual
# 2           18-24 years old    Man    No  Straight / Heterosexual
# 3           18-24 years old    Man    No        Prefer not to say
# 4           35-44 years old    Man    No  Straight / Heterosexual
# 5           25-34 years old    Man    No                      NaN
#
#                                Ethnicity                Accessibility  \
# ResponseId
# 1           White or of European descent            None of the above
# 2           White or of European descent            None of the above
# 3                      Prefer not to say            None of the above
# 4           White or of European descent  I am deaf / hard of hearing
# 5           White or of European descent            None of the above
#
#                  MentalHealth           SurveyLength  \
# ResponseId
# 1           None of the above  Appropriate in length
# 2           None of the above  Appropriate in length
# 3           None of the above  Appropriate in length
# 4                         NaN  Appropriate in length
# 5                         NaN  Appropriate in length
#
#                             SurveyEase  ConvertedCompYearly
# ResponseId
# 1                                 Easy              62268.0
# 2                                 Easy                  NaN
# 3                                 Easy                  NaN
# 4           Neither easy nor difficult                  NaN
# 5                                 Easy                  NaN

# %%
df['ConvertedCompYearly'].head(15)
# Out:
# ResponseId
# 1     62268.0
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10    51552.0
# 11        NaN
# 12    46482.0
# 13    77290.0
# 14        NaN
# 15        NaN
# Name: ConvertedCompYearly, dtype: float64

# %%
df['ConvertedCompYearly'].median()
# Out:
# 56211.0

# %%
df.median()
# Out:
# C:\Users\kuryl001\AppData\Local\Temp\ipykernel_14272\530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# CompTotal              67000.0
# ConvertedCompYearly    56211.0
# dtype: float64

# %%
df.describe()
# Out:
#           CompTotal  ConvertedCompYearly
# count  4.718300e+04         4.684400e+04
# mean   2.119407e+69         1.184262e+05
# std    4.603702e+71         5.272944e+05
# min    0.000000e+00         1.000000e+00
# 25%    1.600000e+04         2.702500e+04
# 50%    6.700000e+04         5.621100e+04
# 75%    1.400000e+05         1.000000e+05
# max    1.000000e+74         4.524131e+07

# %%
df['ConvertedCompYearly'].count()
# Out:
# 46844

# %%
df['NEWOtherComms']
# Out:
# ResponseId
# 1         No
# 2         No
# 3        Yes
# 4         No
# 5         No
#         ...
# 83435     No
# 83436     No
# 83437     No
# 83438     No
# 83439     No
# Name: NEWOtherComms, Length: 83439, dtype: object

# %%
df['NEWOtherComms'].value_counts()
# Out:
# No     53364
# Yes    29464
# Name: NEWOtherComms, dtype: int64

# %%
df['MainBranch'].value_counts(normalize=True)
# Out:
# I am a developer by profession                                                   0.696952
# I am a student who is learning to code                                           0.144165
# I am not primarily a developer, but I write code sometimes as part of my work    0.078836
# I code primarily as a hobby                                                      0.059073
# I used to be a developer by profession, but no longer am                         0.014825
# None of these                                                                    0.006148
# Name: MainBranch, dtype: float64

# %%
df['Country'].value_counts()
# Out:
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
#                                                         ...
# Saint Kitts and Nevis                                       1
# Dominica                                                    1
# Saint Vincent and the Grenadines                            1
# Tuvalu                                                      1
# Papua New Guinea                                            1
# Name: Country, Length: 181, dtype: int64

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('India')
# Out:
#                                         MainBranch          Employment  \
# ResponseId
# 9                   I am a developer by profession  Employed part-time
# 23          I am a student who is learning to code  Student, full-time
# 40          I am a student who is learning to code  Student, part-time
# 50          I am a student who is learning to code  Student, full-time
# 53                  I am a developer by profession  Employed full-time
# ...                                            ...                 ...
# 83400               I am a developer by profession  Employed full-time
# 83407       I am a student who is learning to code  Student, full-time
# 83411       I am a student who is learning to code  Student, part-time
# 83412               I am a developer by profession  Employed full-time
# 83418               I am a developer by profession  Student, full-time
#
#            Country US_State UK_Country  \
# ResponseId
# 9            India      NaN        NaN
# 23           India      NaN        NaN
# 40           India      NaN        NaN
# 50           India      NaN        NaN
# 53           India      NaN        NaN
# ...            ...      ...        ...
# 83400        India      NaN        NaN
# 83407        India      NaN        NaN
# 83411        India      NaN        NaN
# 83412        India      NaN        NaN
# 83418        India      NaN        NaN
#
#                                                       EdLevel     Age1stCode  \
# ResponseId
# 9                Bachelor’s degree (B.A., B.S., B.Eng., etc.)  18 - 24 years
# 23          Some college/university study without earning ...   5 - 10 years
# 40               Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 50          Some college/university study without earning ...  11 - 17 years
# 53            Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  11 - 17 years
# ...                                                       ...            ...
# 83400            Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 83407       Secondary school (e.g. American high school, G...  11 - 17 years
# 83411            Bachelor’s degree (B.A., B.S., B.Eng., etc.)  18 - 24 years
# 83412            Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 83418            Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
#
#                                                     LearnCode YearsCode  \
# ResponseId
# 9                                             Coding Bootcamp         6
# 23                             School;Friend or family member         7
# 40                                                     School         3
# 50          Coding Bootcamp;Other online resources (ex: vi...       NaN
# 53          Other online resources (ex: videos, blogs, etc...         5
# ...                                                       ...       ...
# 83400       Other online resources (ex: videos, blogs, etc...         7
# 83407       Other online resources (ex: videos, blogs, etc...         2
# 83411         Other online resources (ex: videos, blogs, etc)         1
# 83412       Other online resources (ex: videos, blogs, etc...         8
# 83418       School;Friend or family member;Online Courses ...         3
#
#            YearsCodePro                DevType                   OrgSize  \
# ResponseId
# 9                     4   Developer, front-end  10,000 or more employees
# 23                  NaN                    NaN                       NaN
# 40                  NaN                    NaN                       NaN
# 50                  NaN                    NaN                       NaN
# 53                    4  Developer, full-stack  1,000 to 4,999 employees
# ...                 ...                    ...                       ...
# 83400                 6   Developer, front-end        20 to 99 employees
# 83407               NaN                    NaN                       NaN
# 83411               NaN                    NaN                       NaN
# 83412                 5    Developer, back-end      100 to 499 employees
# 83418               NaN                    NaN                       NaN
#
#                      Currency  CompTotal CompFreq  \
# ResponseId
# 9           INR\tIndian rupee        NaN  Monthly
# 23                        NaN        NaN      NaN
# 40                        NaN        NaN      NaN
# 50                        NaN        NaN      NaN
# 53          INR\tIndian rupee        NaN      NaN
# ...                       ...        ...      ...
# 83400       INR\tIndian rupee  2000000.0   Yearly
# 83407                     NaN        NaN      NaN
# 83411                     NaN        NaN      NaN
# 83412       INR\tIndian rupee  3500000.0   Yearly
# 83418                     NaN        NaN      NaN
#
#                                        LanguageHaveWorkedWith  \
# ResponseId
# 9                                         HTML/CSS;JavaScript
# 23                                         C#;HTML/CSS;Python
# 40                C;C#;C++;HTML/CSS;JavaScript;Node.js;Python
# 50          C;HTML/CSS;Java;JavaScript;Kotlin;Node.js;Pyth...
# 53              HTML/CSS;JavaScript;Node.js;Python;TypeScript
# ...                                                       ...
# 83400                          HTML/CSS;JavaScript;TypeScript
# 83407                                            C;C++;Python
# 83411                        C++;JavaScript;Python;TypeScript
# 83412                                     Java;JavaScript;SQL
# 83418                               Bash/Shell;C;C++;Java;SQL
#
#                                        LanguageWantToWorkWith  \
# ResponseId
# 9                                         HTML/CSS;JavaScript
# 23                                         Java;Kotlin;Python
# 40                                                        NaN
# 50                                         Dart;Elixir;Go;SQL
# 53          HTML/CSS;JavaScript;Node.js;PowerShell;Python;...
# ...                                                       ...
# 83400                                      JavaScript;Node.js
# 83407       C;C#;C++;HTML/CSS;JavaScript;Python;Rust;SQL;T...
# 83411                        C++;JavaScript;Python;TypeScript
# 83412                              Go;Java;Kotlin;Node.js;SQL
# 83418                                      Bash/Shell;C++;SQL
#
#                DatabaseHaveWorkedWith  \
# ResponseId
# 9                          PostgreSQL
# 23                                NaN
# 40                            MongoDB
# 50                                NaN
# 53             Firebase;MongoDB;Redis
# ...                               ...
# 83400                             NaN
# 83407                           MySQL
# 83411       MongoDB;PostgreSQL;SQLite
# 83412                           MySQL
# 83418               PostgreSQL;SQLite
#
#                                    DatabaseWantToWorkWith  \
# ResponseId
# 9                                              PostgreSQL
# 23                                                    NaN
# 40                                                    NaN
# 50                                                    NaN
# 53          DynamoDB;Elasticsearch;Firebase;MongoDB;Redis
# ...                                                   ...
# 83400                                                 NaN
# 83407                                        MySQL;Oracle
# 83411                           MongoDB;PostgreSQL;SQLite
# 83412                       Cassandra;Elasticsearch;Redis
# 83418                                          PostgreSQL
#
#                                        PlatformHaveWorkedWith  \
# ResponseId
# 9                                                         AWS
# 23                                                        NaN
# 40                                                     Heroku
# 50                                                     Heroku
# 53          AWS;DigitalOcean;Heroku;Microsoft Azure;Oracle...
# ...                                                       ...
# 83400                                     AWS;Microsoft Azure
# 83407                                                     NaN
# 83411                                                  Heroku
# 83412                                                     AWS
# 83418                                                     AWS
#
#                                        PlatformWantToWorkWith  \
# ResponseId
# 9                                                         NaN
# 23                                                        NaN
# 40                                                        NaN
# 50                                                        NaN
# 53          AWS;DigitalOcean;Google Cloud Platform;Heroku;...
# ...                                                       ...
# 83400                                                     AWS
# 83407                                                     NaN
# 83411                                                  Heroku
# 83412                               AWS;Google Cloud Platform
# 83418                   Google Cloud Platform;Microsoft Azure
#
#               WebframeHaveWorkedWith         WebframeWantToWorkWith  \
# ResponseId
# 9                     Django;FastAPI                 Django;FastAPI
# 23                               NaN                            NaN
# 40           Express;jQuery;React.js                            NaN
# 50           Django;Express;React.js                        Angular
# 53          Angular;Express;React.js       Angular;Express;React.js
# ...                              ...                            ...
# 83400               Angular;React.js  Gatsby;React.js;Svelte;Vue.js
# 83407                            NaN                            NaN
# 83411               Express;React.js               Express;React.js
# 83412                         Spring                         Spring
# 83418                         Spring                  jQuery;Spring
#
#             MiscTechHaveWorkedWith  \
# ResponseId
# 9                              NaN
# 23                             NaN
# 40          Keras;NumPy;TensorFlow
# 50                             NaN
# 53                         Cordova
# ...                            ...
# 83400                 React Native
# 83407                        NumPy
# 83411       Keras;NumPy;TensorFlow
# 83412                          NaN
# 83418                          NaN
#
#                                        MiscTechWantToWorkWith  \
# ResponseId
# 9                                                         NaN
# 23                                                        NaN
# 40                                                        NaN
# 50                                                        NaN
# 53                                                    Cordova
# ...                                                       ...
# 83400                                                     NaN
# 83407       .NET Framework;Flutter;NumPy;React Native;Tens...
# 83411                                  Keras;NumPy;TensorFlow
# 83412                                                     NaN
# 83418                                                     NaN
#
#              ToolsTechHaveWorkedWith                  ToolsTechWantToWorkWith  \
# ResponseId
# 9                         Docker;Git                    Docker;Git;Kubernetes
# 23                          Unity 3D                                      NaN
# 40                     Flow;Unity 3D                                      NaN
# 50                          Git;Yarn                                      NaN
# 53             Docker;Git;Kubernetes                    Docker;Git;Kubernetes
# ...                              ...                                      ...
# 83400                       Git;Yarn                                 Git;Yarn
# 83407                            Git                          Deno;Docker;Git
# 83411       Docker;Git;Unreal Engine                 Docker;Git;Unreal Engine
# 83412                     Docker;Git  Ansible;Docker;Git;Kubernetes;Terraform
# 83418                     Docker;Git                               Docker;Git
#
#                                  NEWCollabToolsHaveWorkedWith  \
# ResponseId
# 9                                        PyCharm;Sublime Text
# 23                                             Android Studio
# 40            IPython/Jupyter;Sublime Text;Visual Studio Code
# 50          Android Studio;Atom;Notepad++;Sublime Text;Vis...
# 53                                   Visual Studio Code;Xcode
# ...                                                       ...
# 83400                                  Vim;Visual Studio Code
# 83407                              PyCharm;Visual Studio Code
# 83411       Android Studio;Atom;Eclipse;IntelliJ;IPython/J...
# 83412                 Eclipse;Sublime Text;Visual Studio Code
# 83418                         IntelliJ;Vim;Visual Studio Code
#
#                                  NEWCollabToolsWantToWorkWith        OpSys  \
# ResponseId
# 9                                        PyCharm;Sublime Text      Windows
# 23                                             Android Studio      Windows
# 40                                                        NaN  Linux-based
# 50                                                        NaN      Windows
# 53                                   Visual Studio Code;Xcode        MacOS
# ...                                                       ...          ...
# 83400                         Vim;Visual Studio Code;Webstorm        MacOS
# 83407                                                     NaN      Windows
# 83411       IPython/Jupyter;PyCharm;Vim;Visual Studio;Visu...      Windows
# 83412                           Eclipse;IntelliJ;Sublime Text        MacOS
# 83418                         IntelliJ;Vim;Visual Studio Code  Linux-based
#
#                                                      NEWStuck  \
# ResponseId
# 9                        Visit Stack Overflow;Google it;Panic
# 23          Visit Stack Overflow;Google it;Watch help / tu...
# 40          Visit Stack Overflow;Go for a walk or other ph...
# 50          Visit Stack Overflow;Go for a walk or other ph...
# 53          Visit Stack Overflow;Go for a walk or other ph...
# ...                                                       ...
# 83400       Visit Stack Overflow;Go for a walk or other ph...
# 83407       Visit Stack Overflow;Google it;Do other work a...
# 83411                                         Google it;Panic
# 83412       Visit Stack Overflow;Google it;Watch help / tu...
# 83418       Visit Stack Overflow;Go for a walk or other ph...
#
#                                                    NEWSOSites  \
# ResponseId
# 9                               Stack Overflow;Stack Exchange
# 23                              Stack Overflow;Stack Exchange
# 40                              Stack Overflow;Stack Exchange
# 50                                             Stack Overflow
# 53                                             Stack Overflow
# ...                                                       ...
# 83400                           Stack Overflow;Stack Exchange
# 83407                           Stack Overflow;Stack Exchange
# 83411                           Stack Overflow;Stack Exchange
# 83412       Stack Overflow;Stack Exchange;Stack Overflow f...
# 83418       Stack Overflow;Stack Exchange;Stack Overflow f...
#
#                                 SOVisitFreq SOAccount  \
# ResponseId
# 9                      A few times per week       Yes
# 23                   Multiple times per day       Yes
# 40                   Multiple times per day       Yes
# 50                   Multiple times per day       Yes
# 53                   Multiple times per day       Yes
# ...                                     ...       ...
# 83400                 Daily or almost daily       Yes
# 83407       A few times per month or weekly       Yes
# 83411                Multiple times per day       Yes
# 83412                 Daily or almost daily       Yes
# 83418                Multiple times per day       Yes
#
#                                                    SOPartFreq  \
# ResponseId
# 9                         Less than once per month or monthly
# 23                                     Multiple times per day
# 40                            A few times per month or weekly
# 50                                       A few times per week
# 53                        Less than once per month or monthly
# ...                                                       ...
# 83400                                    A few times per week
# 83407       I have never participated in Q&A on Stack Over...
# 83411       I have never participated in Q&A on Stack Over...
# 83412                     Less than once per month or monthly
# 83418                                   Daily or almost daily
#
#                      SOComm NEWOtherComms                 Age Gender Trans  \
# ResponseId
# 9           Yes, definitely            No     25-34 years old    Man    No
# 23          Yes, definitely            No  Under 18 years old    Man    No
# 40            Yes, somewhat           Yes     18-24 years old  Woman    No
# 50          Yes, definitely            No     18-24 years old    Man    No
# 53          Yes, definitely            No     25-34 years old    Man    No
# ...                     ...           ...                 ...    ...   ...
# 83400       Yes, definitely            No     25-34 years old    Man    No
# 83407        No, not really           Yes     18-24 years old    Man    No
# 83411       Yes, definitely            No     18-24 years old    Man    No
# 83412         Yes, somewhat            No     25-34 years old    Man    No
# 83418       Yes, definitely           Yes     18-24 years old    Man    No
#
#                           Sexuality                     Ethnicity  \
# ResponseId
# 9                               NaN                   South Asian
# 23                Prefer not to say             Prefer not to say
# 40          Straight / Heterosexual  White or of European descent
# 50          Straight / Heterosexual                   South Asian
# 53                Prefer not to say                  I don't know
# ...                             ...                           ...
# 83400       Straight / Heterosexual                   South Asian
# 83407       Straight / Heterosexual                   South Asian
# 83411       Straight / Heterosexual                  I don't know
# 83412       Straight / Heterosexual                   South Asian
# 83418                           NaN                   South Asian
#
#                 Accessibility  \
# ResponseId
# 9                         NaN
# 23          None of the above
# 40          None of the above
# 50          None of the above
# 53          None of the above
# ...                       ...
# 83400       None of the above
# 83407       None of the above
# 83411       None of the above
# 83412       None of the above
# 83418                     NaN
#
#                                                  MentalHealth  \
# ResponseId
# 9           I have a concentration and/or memory disorder ...
# 23                                          None of the above
# 40          I have a concentration and/or memory disorder ...
# 50                                          None of the above
# 53                                          None of the above
# ...                                                       ...
# 83400                                       None of the above
# 83407                                       None of the above
# 83411                                       None of the above
# 83412                                       None of the above
# 83418                                                     NaN
#
#                      SurveyLength                  SurveyEase  \
# ResponseId
# 9           Appropriate in length                        Easy
# 23          Appropriate in length                        Easy
# 40          Appropriate in length                        Easy
# 50          Appropriate in length                        Easy
# 53                       Too long  Neither easy nor difficult
# ...                           ...                         ...
# 83400                   Too short                        Easy
# 83407       Appropriate in length                        Easy
# 83411       Appropriate in length  Neither easy nor difficult
# 83412       Appropriate in length                        Easy
# 83418       Appropriate in length  Neither easy nor difficult
#
#             ConvertedCompYearly
# ResponseId
# 9                           NaN
# 23                          NaN
# 40                          NaN
# 50                          NaN
# 53                          NaN
# ...                         ...
# 83400                   27923.0
# 83407                       NaN
# 83411                       NaN
# 83412                   48866.0
# 83418                       NaN
#
# [10511 rows x 47 columns]

# %%
filt = (df['Country'] == "India")

# %%
df.loc[filt]['MainBranch'].value_counts()
# Out:
# I am a developer by profession                                                   6612
# I am a student who is learning to code                                           2817
# I code primarily as a hobby                                                       489
# I am not primarily a developer, but I write code sometimes as part of my work     462
# I used to be a developer by profession, but no longer am                           93
# None of these                                                                      38
# Name: MainBranch, dtype: int64

# %%
country_grp['MainBranch'].value_counts(normalize=True).loc['Ukraine']
# Out:
# MainBranch
# I am a developer by profession                                                   0.818182
# I am a student who is learning to code                                           0.088312
# I code primarily as a hobby                                                      0.038961
# I am not primarily a developer, but I write code sometimes as part of my work    0.037662
# I used to be a developer by profession, but no longer am                         0.012987
# None of these                                                                    0.003896
# Name: MainBranch, dtype: float64

# %%
country_grp['ConvertedCompYearly'].median().loc['Germany']
# Out:
# 64859.0

# %%
country_grp['ConvertedCompYearly'].agg(['median', 'mean']).loc['Canada']
# Out:
# median     75631.000000
# mean      135732.563006
# Name: Canada, dtype: float64

# %%
filt = df['Country'] == "India"
df.loc[filt]['LanguageHaveWorkedWith'].str.contains('Python').sum()
# Out:
# 5233

# %%
country_grp['LanguageHaveWorkedWith'].str.contains('Python').sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [80], in <module>
# ----> 1 country_grp['LanguageHaveWorkedWith'].str.contains('Python').sum()
#
# File c:\users\kuryl001\documents\github\pandas_tutorial\venv\lib\site-packages\pandas\core\groupby\groupby.py:911, in GroupBy.__getattr__(self, attr)
#     908 if attr in self.obj:
#     909     return self[attr]
# --> 911 raise AttributeError(
#     912     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     913 )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              20
# Albania                                  30
# Algeria                                  19
# Andorra                                   4
# Angola                                    5
#                                        ...
# Venezuela, Bolivarian Republic of...     43
# Viet Nam                                173
# Yemen                                     6
# Zambia                                   12
# Zimbabwe                                 17
# Name: LanguageHaveWorkedWith, Length: 181, dtype: int64

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
#                                                         ...
# Saint Kitts and Nevis                                       1
# Dominica                                                    1
# Saint Vincent and the Grenadines                            1
# Tuvalu                                                      1
# Papua New Guinea                                            1
# Name: Country, Length: 181, dtype: int64

# %%
country_uses_python = country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              20
# Albania                                  30
# Algeria                                  19
# Andorra                                   4
# Angola                                    5
#                                        ...
# Venezuela, Bolivarian Republic of...     43
# Viet Nam                                173
# Yemen                                     6
# Zambia                                   12
# Zimbabwe                                 17
# Name: LanguageHaveWorkedWith, Length: 181, dtype: int64

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis='columns')
python_df
# Out:
#                                                     Country  \
# United States of America                              15288
# India                                                 10511
# Germany                                                5625
# United Kingdom of Great Britain and Northern Ir...     4475
# Canada                                                 3012
# ...                                                     ...
# Saint Kitts and Nevis                                     1
# Dominica                                                  1
# Saint Vincent and the Grenadines                          1
# Tuvalu                                                    1
# Papua New Guinea                                          1
#
#                                                     LanguageHaveWorkedWith
# United States of America                                              7975
# India                                                                 5233
# Germany                                                               2713
# United Kingdom of Great Britain and Northern Ir...                    2149
# Canada                                                                1593
# ...                                                                    ...
# Saint Kitts and Nevis                                                    0
# Dominica                                                                 1
# Saint Vincent and the Grenadines                                         0
# Tuvalu                                                                   1
# Papua New Guinea                                                         0
#
# [181 rows x 2 columns]

# %%
python_df.rename(columns={'Country': 'NumRespondents', 'LanguageHaveWorkedWith': 'NumKnowsPython'}, inplace=True)
python_df
# Out:
#                                                     NumRespondents  \
# United States of America                                     15288
# India                                                        10511
# Germany                                                       5625
# United Kingdom of Great Britain and Northern Ir...            4475
# Canada                                                        3012
# ...                                                            ...
# Saint Kitts and Nevis                                            1
# Dominica                                                         1
# Saint Vincent and the Grenadines                                 1
# Tuvalu                                                           1
# Papua New Guinea                                                 1
#
#                                                     NumKnowsPython
# United States of America                                      7975
# India                                                         5233
# Germany                                                       2713
# United Kingdom of Great Britain and Northern Ir...            2149
# Canada                                                        1593
# ...                                                            ...
# Saint Kitts and Nevis                                            0
# Dominica                                                         1
# Saint Vincent and the Grenadines                                 0
# Tuvalu                                                           1
# Papua New Guinea                                                 0
#
# [181 rows x 2 columns]

# %%
python_df['PctKnowsPython']= (python_df['NumKnowsPython']/python_df['NumRespondents']) * 100
python_df
# Out:
#                                                     NumRespondents  \
# United States of America                                     15288
# India                                                        10511
# Germany                                                       5625
# United Kingdom of Great Britain and Northern Ir...            4475
# Canada                                                        3012
# ...                                                            ...
# Saint Kitts and Nevis                                            1
# Dominica                                                         1
# Saint Vincent and the Grenadines                                 1
# Tuvalu                                                           1
# Papua New Guinea                                                 1
#
#                                                     NumKnowsPython  \
# United States of America                                      7975
# India                                                         5233
# Germany                                                       2713
# United Kingdom of Great Britain and Northern Ir...            2149
# Canada                                                        1593
# ...                                                            ...
# Saint Kitts and Nevis                                            0
# Dominica                                                         1
# Saint Vincent and the Grenadines                                 0
# Tuvalu                                                           1
# Papua New Guinea                                                 0
#
#                                                     PctKnowsPython
# United States of America                                 52.165097
# India                                                    49.785939
# Germany                                                  48.231111
# United Kingdom of Great Britain and Northern Ir...       48.022346
# Canada                                                   52.888446
# ...                                                            ...
# Saint Kitts and Nevis                                     0.000000
# Dominica                                                100.000000
# Saint Vincent and the Grenadines                          0.000000
# Tuvalu                                                  100.000000
# Papua New Guinea                                          0.000000
#
# [181 rows x 3 columns]

# %%
python_df.sort_values('PctKnowsPython', ascending=False, inplace=True)
python_df
# Out:
#                                   NumRespondents  NumKnowsPython  \
# Tuvalu                                         1               1
# Brunei Darussalam                              1               1
# Sierra Leone                                   2               2
# Dominica                                       1               1
# Liechtenstein                                  1               1
# ...                                          ...             ...
# Mali                                           2               0
# Saint Kitts and Nevis                          1               0
# Saint Vincent and the Grenadines               1               0
# Lesotho                                        4               0
# Papua New Guinea                               1               0
#
#                                   PctKnowsPython
# Tuvalu                                     100.0
# Brunei Darussalam                          100.0
# Sierra Leone                               100.0
# Dominica                                   100.0
# Liechtenstein                              100.0
# ...                                          ...
# Mali                                         0.0
# Saint Kitts and Nevis                        0.0
# Saint Vincent and the Grenadines             0.0
# Lesotho                                      0.0
# Papua New Guinea                             0.0
#
# [181 rows x 3 columns]

# %%
python_df.head(48)
# Out:
#                                     NumRespondents  NumKnowsPython  \
# Tuvalu                                           1               1
# Brunei Darussalam                                1               1
# Sierra Leone                                     2               2
# Dominica                                         1               1
# Liechtenstein                                    1               1
# Burundi                                          5               4
# Namibia                                         12               9
# Burkina Faso                                     4               3
# Bahamas                                          7               5
# Qatar                                           29              20
# Liberia                                          3               2
# Saint Lucia                                      3               2
# Cuba                                            34              22
# Iceland                                         43              27
# Bhutan                                           5               3
# Isle of Man                                      5               3
# Haiti                                            5               3
# Belize                                           5               3
# Singapore                                      339             203
# Republic of Korea                               54              31
# Senegal                                         28              16
# Guyana                                           7               4
# Israel                                         913             515
# Maldives                                        16               9
# Oman                                            20              11
# Mauritius                                       31              17
# Zambia                                          22              12
# Chile                                          230             123
# Hong Kong (S.A.R.)                             198             105
# Canada                                        3012            1593
# Nepal                                          337             178
# Tunisia                                        150              79
# France                                        2708            1423
# Uganda                                          63              33
# United States of America                     15288            7975
# Palestine                                       25              13
# Slovenia                                       235             122
# Azerbaijan                                      64              33
# Luxembourg                                      51              26
# Switzerland                                    922             470
# Australia                                     1646             831
# Kenya                                          263             132
# Democratic Republic of the Congo                10               5
# Guinea                                           2               1
# Jamaica                                         20              10
# Nomadic                                         54              27
# Micronesia, Federated States of...               2               1
# Chad                                             2               1
#
#                                     PctKnowsPython
# Tuvalu                                  100.000000
# Brunei Darussalam                       100.000000
# Sierra Leone                            100.000000
# Dominica                                100.000000
# Liechtenstein                           100.000000
# Burundi                                  80.000000
# Namibia                                  75.000000
# Burkina Faso                             75.000000
# Bahamas                                  71.428571
# Qatar                                    68.965517
# Liberia                                  66.666667
# Saint Lucia                              66.666667
# Cuba                                     64.705882
# Iceland                                  62.790698
# Bhutan                                   60.000000
# Isle of Man                              60.000000
# Haiti                                    60.000000
# Belize                                   60.000000
# Singapore                                59.882006
# Republic of Korea                        57.407407
# Senegal                                  57.142857
# Guyana                                   57.142857
# Israel                                   56.407448
# Maldives                                 56.250000
# Oman                                     55.000000
# Mauritius                                54.838710
# Zambia                                   54.545455
# Chile                                    53.478261
# Hong Kong (S.A.R.)                       53.030303
# Canada                                   52.888446
# Nepal                                    52.818991
# Tunisia                                  52.666667
# France                                   52.548006
# Uganda                                   52.380952
# United States of America                 52.165097
# Palestine                                52.000000
# Slovenia                                 51.914894
# Azerbaijan                               51.562500
# Luxembourg                               50.980392
# Switzerland                              50.976139
# Australia                                50.486027
# Kenya                                    50.190114
# Democratic Republic of the Congo         50.000000
# Guinea                                   50.000000
# Jamaica                                  50.000000
# Nomadic                                  50.000000
# Micronesia, Federated States of...       50.000000
# Chad                                     50.000000

# %%
python_df.loc['Ukraine']
# Out:
# NumRespondents    770.000000
# NumKnowsPython    271.000000
# PctKnowsPython     35.194805
# Name: Ukraine, dtype: float64

# %%
import pandas as pd

# %%
na_vals = ['NA', 'Missing']
df = pd.read_csv('data/survey_results_public.csv', index_col='ResponseId', na_values=na_vals)
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='qname')

# %%
pd.set_option('display.max_columns', 48)
pd.set_option('display.max_rows', 48)

# %%
df.head()
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# 3                                          Student, full-time
# 4                                          Employed full-time
# 5           Independent contractor, freelancer, or self-em...
#
#                                                       Country US_State  \
# ResponseId
# 1                                                    Slovakia      NaN
# 2                                                 Netherlands      NaN
# 3                                          Russian Federation      NaN
# 4                                                     Austria      NaN
# 5           United Kingdom of Great Britain and Northern I...      NaN
#
#            UK_Country                                            EdLevel  \
# ResponseId
# 1                 NaN  Secondary school (e.g. American high school, G...
# 2                 NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3                 NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4                 NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5             England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                Age1stCode                                          LearnCode  \
# ResponseId
# 1           18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 2           11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3           11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 4           11 - 17 years                                                NaN
# 5            5 - 10 years                            Friend or family member
#
#            YearsCode YearsCodePro  \
# ResponseId
# 1                NaN          NaN
# 2                  7          NaN
# 3                NaN          NaN
# 4                NaN          NaN
# 5                 17           10
#
#                                                       DevType  \
# ResponseId
# 1                                           Developer, mobile
# 2                                                         NaN
# 3                                                         NaN
# 4                                        Developer, front-end
# 5           Developer, desktop or enterprise applications;...
#
#                                                       OrgSize  \
# ResponseId
# 1                                          20 to 99 employees
# 2                                                         NaN
# 3                                                         NaN
# 4                                        100 to 499 employees
# 5           Just me - I am a freelancer, sole proprietor, ...
#
#                        Currency  CompTotal CompFreq  \
# ResponseId
# 1             EUR European Euro     4800.0  Monthly
# 2                           NaN        NaN      NaN
# 3                           NaN        NaN      NaN
# 4             EUR European Euro        NaN  Monthly
# 5           GBP\tPound sterling        NaN      NaN
#
#                                    LanguageHaveWorkedWith  \
# ResponseId
# 1           C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 2                                       JavaScript;Python
# 3                                Assembly;C;Python;R;Rust
# 4                                   JavaScript;TypeScript
# 5                          Bash/Shell;HTML/CSS;Python;SQL
#
#                     LanguageWantToWorkWith          DatabaseHaveWorkedWith  \
# ResponseId
# 1                                    Swift               PostgreSQL;SQLite
# 2                                      NaN                      PostgreSQL
# 3                        Julia;Python;Rust                          SQLite
# 4                    JavaScript;TypeScript                             NaN
# 5           Bash/Shell;HTML/CSS;Python;SQL  Elasticsearch;PostgreSQL;Redis
#
#                               DatabaseWantToWorkWith PlatformHaveWorkedWith  \
# ResponseId
# 1                                             SQLite                    NaN
# 2                                                NaN                    NaN
# 3                                             SQLite                 Heroku
# 4                                                NaN                    NaN
# 5           Cassandra;Elasticsearch;PostgreSQL;Redis                    NaN
#
#            PlatformWantToWorkWith WebframeHaveWorkedWith  \
# ResponseId
# 1                             NaN        Laravel;Symfony
# 2                             NaN   Angular;Flask;Vue.js
# 3                             NaN                  Flask
# 4                             NaN         Angular;jQuery
# 5                             NaN                  Flask
#
#            WebframeWantToWorkWith                 MiscTechHaveWorkedWith  \
# ResponseId
# 1                             NaN                                    NaN
# 2                             NaN                                Cordova
# 3                           Flask  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 4                  Angular;jQuery                                    NaN
# 5                           Flask       Apache Spark;Hadoop;NumPy;Pandas
#
#                                  MiscTechWantToWorkWith  \
# ResponseId
# 1                                                   NaN
# 2                                                   NaN
# 3           Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 4                                                   NaN
# 5                                   Hadoop;NumPy;Pandas
#
#                ToolsTechHaveWorkedWith     ToolsTechWantToWorkWith  \
# ResponseId
# 1                                  NaN                         NaN
# 2                      Docker;Git;Yarn                         Git
# 3                                  NaN                         NaN
# 4                                  NaN                         NaN
# 5           Docker;Git;Kubernetes;Yarn  Docker;Git;Kubernetes;Yarn
#
#                                  NEWCollabToolsHaveWorkedWith  \
# ResponseId
# 1                                              PHPStorm;Xcode
# 2                   Android Studio;IntelliJ;Notepad++;PyCharm
# 3           IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 4                                                         NaN
# 5                  Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
#
#                                  NEWCollabToolsWantToWorkWith        OpSys  \
# ResponseId
# 1                                                  Atom;Xcode        MacOS
# 2                                                         NaN      Windows
# 3           IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 4                                                         NaN      Windows
# 5           Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
#
#                                                      NEWStuck  \
# ResponseId
# 1           Call a coworker or friend;Visit Stack Overflow...
# 2                              Visit Stack Overflow;Google it
# 3           Visit Stack Overflow;Google it;Watch help / tu...
# 4           Call a coworker or friend;Visit Stack Overflow...
# 5           Visit Stack Overflow;Go for a walk or other ph...
#
#                                NEWSOSites             SOVisitFreq SOAccount  \
# ResponseId
# 1                          Stack Overflow  Multiple times per day       Yes
# 2                          Stack Overflow   Daily or almost daily       Yes
# 3           Stack Overflow;Stack Exchange  Multiple times per day       Yes
# 4                          Stack Overflow   Daily or almost daily       Yes
# 5           Stack Overflow;Stack Exchange   Daily or almost daily       Yes
#
#                                  SOPartFreq           SOComm NEWOtherComms  \
# ResponseId
# 1           A few times per month or weekly  Yes, definitely            No
# 2                     Daily or almost daily  Yes, definitely            No
# 3                    Multiple times per day  Yes, definitely           Yes
# 4                     Daily or almost daily          Neutral            No
# 5                      A few times per week    Yes, somewhat            No
#
#                         Age Gender Trans                Sexuality  \
# ResponseId
# 1           25-34 years old    Man    No  Straight / Heterosexual
# 2           18-24 years old    Man    No  Straight / Heterosexual
# 3           18-24 years old    Man    No        Prefer not to say
# 4           35-44 years old    Man    No  Straight / Heterosexual
# 5           25-34 years old    Man    No                      NaN
#
#                                Ethnicity                Accessibility  \
# ResponseId
# 1           White or of European descent            None of the above
# 2           White or of European descent            None of the above
# 3                      Prefer not to say            None of the above
# 4           White or of European descent  I am deaf / hard of hearing
# 5           White or of European descent            None of the above
#
#                  MentalHealth           SurveyLength  \
# ResponseId
# 1           None of the above  Appropriate in length
# 2           None of the above  Appropriate in length
# 3           None of the above  Appropriate in length
# 4                         NaN  Appropriate in length
# 5                         NaN  Appropriate in length
#
#                             SurveyEase  ConvertedCompYearly
# ResponseId
# 1                                 Easy              62268.0
# 2                                 Easy                  NaN
# 3                                 Easy                  NaN
# 4           Neither easy nor difficult                  NaN
# 5                                 Easy                  NaN

# %%
df['YearsCode'].head(10)
# Out:
# ResponseId
# 1     NaN
# 2       7
# 3     NaN
# 4     NaN
# 5      17
# 6     NaN
# 7       3
# 8       4
# 9       6
# 10      7
# Name: YearsCode, dtype: object

# %%
df['YearsCode'] = df['YearsCode'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [95], in <module>
# ----> 1 df['YearsCode'] = df['YearsCode'].astype(float)
#
# File c:\users\kuryl001\documents\github\pandas_tutorial\venv\lib\site-packages\pandas\core\generic.py:5815, in NDFrame.astype(self, dtype, copy, errors)
#    5808     results = [
#    5809         self.iloc[:, i].astype(dtype, copy=copy)
#    5810         for i in range(len(self.columns))
#    5811     ]
#    5813 else:
#    5814     # else, only a single dtype is given
# -> 5815     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816     return self._constructor(new_data).__finalize__(self, method="astype")
#    5818 # GH 33113: handle empty frame or series
#
# File c:\users\kuryl001\documents\github\pandas_tutorial\venv\lib\site-packages\pandas\core\internals\managers.py:418, in BaseBlockManager.astype(self, dtype, copy, errors)
#     417 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File c:\users\kuryl001\documents\github\pandas_tutorial\venv\lib\site-packages\pandas\core\internals\managers.py:327, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     325         applied = b.apply(f, **kwargs)
#     326     else:
# --> 327         applied = getattr(b, f)(**kwargs)
#     328 except (TypeError, NotImplementedError):
#     329     if not ignore_failures:
#
# File c:\users\kuryl001\documents\github\pandas_tutorial\venv\lib\site-packages\pandas\core\internals\blocks.py:591, in Block.astype(self, dtype, copy, errors)
#     573 """
#     574 Coerce to the new dtype.
#     575
#    (...)
#     587 Block
#     588 """
#     589 values = self.values
# --> 591 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     593 new_values = maybe_coerce_values(new_values)
#     594 newb = self.make_block(new_values)
#
# File c:\users\kuryl001\documents\github\pandas_tutorial\venv\lib\site-packages\pandas\core\dtypes\cast.py:1309, in astype_array_safe(values, dtype, copy, errors)
#    1306 dtype = pandas_dtype(dtype)
#    1308 try:
# -> 1309     new_values = astype_array(values, dtype, copy=copy)
#    1310 except (ValueError, TypeError):
#    1311     # e.g. astype_nansafe can fail on object-dtype of strings
#    1312     #  trying to convert to float
#    1313     if errors == "ignore":
#
# File c:\users\kuryl001\documents\github\pandas_tutorial\venv\lib\site-packages\pandas\core\dtypes\cast.py:1257, in astype_array(values, dtype, copy)
#    1254     values = values.astype(dtype, copy=copy)
#    1256 else:
# -> 1257     values = astype_nansafe(values, dtype, copy=copy)
#    1259 # in pandas we don't store numpy str dtypes, so convert to object
#    1260 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File c:\users\kuryl001\documents\github\pandas_tutorial\venv\lib\site-packages\pandas\core\dtypes\cast.py:1201, in astype_nansafe(arr, dtype, copy, skipna)
#    1197     raise ValueError(msg)
#    1199 if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#    1200     # Explicit copy, or required since NumPy can't view from / to object.
# -> 1201     return arr.astype(dtype, copy=True)
#    1203 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: 'Less than 1 year'

# %%
df['YearsCode'].unique()
# Out:
# array([nan, '7', '17', '3', '4', '6', '16', '12', '15', '10', '40', '9',
#        '26', '14', '39', '20', '8', '19', '5', 'Less than 1 year', '22',
#        '2', '1', '34', '21', '13', '25', '24', '30', '31', '18', '38',
#        'More than 50 years', '27', '41', '42', '35', '23', '28', '11',
#        '37', '44', '43', '36', '33', '45', '29', '50', '46', '32', '47',
#        '49', '48'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year', 0, inplace=True)

# %%
df['YearsCode'].replace('More than 50 years', 51, inplace=True)

# %%
df['YearsCode'].unique()
# Out:
# array([nan, '7', '17', '3', '4', '6', '16', '12', '15', '10', '40', '9',
#        '26', '14', '39', '20', '8', '19', '5', 0, '22', '2', '1', '34',
#        '21', '13', '25', '24', '30', '31', '18', '38', 51, '27', '41',
#        '42', '35', '23', '28', '11', '37', '44', '43', '36', '33', '45',
#        '29', '50', '46', '32', '47', '49', '48'], dtype=object)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 12.338200169032717

# %%
df['YearsCode'].median()
# Out:
# 10.0

# %%
import pandas as pd

# %%
df = pd.read_csv('data/ETH_1h.csv')

# %%
df
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
df.shape
# Out:
# (23674, 7)

# %%
df.loc[0, 'Date'].day_name()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [107], in <module>
# ----> 1 df.loc[0, 'Date'].day_name()
#
# AttributeError: 'str' object has no attribute 'day_name'

# %%
df['Date'] = pd.to_datetime(df['Date'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\users\kuryl001\documents\github\pandas_tutorial\venv\lib\site-packages\pandas\core\arrays\datetimes.py:2192, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2191 try:
# -> 2192     values, tz_parsed = conversion.datetime_to_datetime64(data.ravel("K"))
#    2193     # If tzaware, these values represent unix timestamps, so we
#    2194     #  return them as i8 to distinguish from wall times
#
# File c:\users\kuryl001\documents\github\pandas_tutorial\venv\lib\site-packages\pandas\_libs\tslibs\conversion.pyx:359, in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# Input In [108], in <module>
# ----> 1 df['Date'] = pd.to_datetime(df['Date'])
#
# File c:\users\kuryl001\documents\github\pandas_tutorial\venv\lib\site-packages\pandas\core\tools\datetimes.py:887, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     885         result = arg.map(cache_array)
#     886     else:
# --> 887         values = convert_listlike(arg._values, format)
#     888         result = arg._constructor(values, index=arg.index, name=arg.name)
#     889 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File c:\users\kuryl001\documents\github\pandas_tutorial\venv\lib\site-packages\pandas\core\tools\datetimes.py:401, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     399 assert format is None or infer_datetime_format
#     400 utc = tz == "utc"
# --> 401 result, tz_parsed = objects_to_datetime64ns(
#     402     arg,
#     403     dayfirst=dayfirst,
#     404     yearfirst=yearfirst,
#     405     utc=utc,
#     406     errors=errors,
#     407     require_iso8601=require_iso8601,
#     408     allow_object=True,
#     409 )
#     411 if tz_parsed is not None:
#     412     # We can take a shortcut since the datetime64 numpy array
#     413     # is in UTC
#     414     dta = DatetimeArray(result, dtype=tz_to_dtype(tz_parsed))
#
# File c:\users\kuryl001\documents\github\pandas_tutorial\venv\lib\site-packages\pandas\core\arrays\datetimes.py:2198, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2196         return values.view("i8"), tz_parsed
#    2197     except (ValueError, TypeError):
# -> 2198         raise err
#    2200 if tz_parsed is not None:
#    2201     # We can take a shortcut since the datetime64 numpy array
#    2202     #  is in UTC
#    2203     # Return i8 values to denote unix timestamps
#    2204     return result.view("i8"), tz_parsed
#
# File c:\users\kuryl001\documents\github\pandas_tutorial\venv\lib\site-packages\pandas\core\arrays\datetimes.py:2180, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2178 order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2179 try:
# -> 2180     result, tz_parsed = tslib.array_to_datetime(
#    2181         data.ravel("K"),
#    2182         errors=errors,
#    2183         utc=utc,
#    2184         dayfirst=dayfirst,
#    2185         yearfirst=yearfirst,
#    2186         require_iso8601=require_iso8601,
#    2187         allow_mixed=allow_mixed,
#    2188     )
#    2189     result = result.reshape(data.shape, order=order)
#    2190 except ValueError as err:
#
# File c:\users\kuryl001\documents\github\pandas_tutorial\venv\lib\site-packages\pandas\_libs\tslib.pyx:379, in pandas._libs.tslib.array_to_datetime()
#
# File c:\users\kuryl001\documents\github\pandas_tutorial\venv\lib\site-packages\pandas\_libs\tslib.pyx:611, in pandas._libs.tslib.array_to_datetime()
#
# File c:\users\kuryl001\documents\github\pandas_tutorial\venv\lib\site-packages\pandas\_libs\tslib.pyx:749, in pandas._libs.tslib._array_to_datetime_object()
#
# File c:\users\kuryl001\documents\github\pandas_tutorial\venv\lib\site-packages\pandas\_libs\tslib.pyx:740, in pandas._libs.tslib._array_to_datetime_object()
#
# File c:\users\kuryl001\documents\github\pandas_tutorial\venv\lib\site-packages\pandas\_libs\tslibs\parsing.pyx:257, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File c:\users\kuryl001\documents\github\pandas_tutorial\venv\lib\site-packages\dateutil\parser\_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1366     return parser(parserinfo).parse(timestr, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File c:\users\kuryl001\documents\github\pandas_tutorial\venv\lib\site-packages\dateutil\parser\_parser.py:643, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     640 res, skipped_tokens = self._parse(timestr, **kwargs)
#     642 if res is None:
# --> 643     raise ParserError("Unknown string format: %s", timestr)
#     645 if len(res) == 0:
#     646     raise ParserError("String does not contain a date: %s", timestr)
#
# ParserError: Unknown string format: 2020-03-13 08-PM

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d %I-%p')

# %%
df['Date']
# Out:
# 0       2020-03-13 20:00:00
# 1       2020-03-13 19:00:00
# 2       2020-03-13 18:00:00
# 3       2020-03-13 17:00:00
# 4       2020-03-13 16:00:00
#                 ...
# 23669   2017-07-01 15:00:00
# 23670   2017-07-01 14:00:00
# 23671   2017-07-01 13:00:00
# 23672   2017-07-01 12:00:00
# 23673   2017-07-01 11:00:00
# Name: Date, Length: 23674, dtype: datetime64[ns]

# %%
df.loc[0, 'Date'].day_name()
# Out:
# 'Friday'

# %%
from datetime import datetime
d_parser = lambda x: datetime.strptime(x, '%Y-%m-%d %I-%p')
df = pd.read_csv('data/ETH_1h.csv', parse_dates=['Date'], date_parser=d_parser)

# %%
df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
df.loc[0, 'Date'].day_name()
# Out:
# 'Friday'

# %%
df['Date'].dt.day_name()
# Out:
# 0          Friday
# 1          Friday
# 2          Friday
# 3          Friday
# 4          Friday
#            ...
# 23669    Saturday
# 23670    Saturday
# 23671    Saturday
# 23672    Saturday
# 23673    Saturday
# Name: Date, Length: 23674, dtype: object

# %%
df['DayOfWeek'] = df['Date'].dt.day_name()

# %%
df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#       DayOfWeek
# 0        Friday
# 1        Friday
# 2        Friday
# 3        Friday
# 4        Friday
# ...         ...
# 23669  Saturday
# 23670  Saturday
# 23671  Saturday
# 23672  Saturday
# 23673  Saturday
#
# [23674 rows x 8 columns]

# %%
df['Date'].min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
df['Date'].max()
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
df['Date'].max() - df['Date'].min()
# Out:
# Timedelta('986 days 09:00:00')

# %%
filt = (df['Date'] >= '2019') & (df['Date'] < '2020')
df.loc[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       DayOfWeek
# 1749    Tuesday
# 1750    Tuesday
# 1751    Tuesday
# 1752    Tuesday
# 1753    Tuesday
# ...         ...
# 10504   Tuesday
# 10505   Tuesday
# 10506   Tuesday
# 10507   Tuesday
# 10508   Tuesday
#
# [8760 rows x 8 columns]

# %%
dt_format = '%Y-%m-%d'
filt = (df['Date'] >= datetime.strptime('2019-01-01', dt_format)) & (df['Date'] < datetime.strptime('2020-01-01', dt_format))
df.loc[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       DayOfWeek
# 1749    Tuesday
# 1750    Tuesday
# 1751    Tuesday
# 1752    Tuesday
# 1753    Tuesday
# ...         ...
# 10504   Tuesday
# 10505   Tuesday
# 10506   Tuesday
# 10507   Tuesday
# 10508   Tuesday
#
# [8760 rows x 8 columns]

# %%
df.set_index('Date', inplace=True)

# %%
df
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#                     DayOfWeek
# Date
# 2020-03-13 20:00:00    Friday
# 2020-03-13 19:00:00    Friday
# 2020-03-13 18:00:00    Friday
# 2020-03-13 17:00:00    Friday
# 2020-03-13 16:00:00    Friday
# ...                       ...
# 2017-07-01 15:00:00  Saturday
# 2017-07-01 14:00:00  Saturday
# 2017-07-01 13:00:00  Saturday
# 2017-07-01 12:00:00  Saturday
# 2017-07-01 11:00:00  Saturday
#
# [23674 rows x 7 columns]

# %%
df.loc['2019-12']
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                     ...     ...     ...     ...     ...         ...
# 2019-12-01 04:00:00  ETHUSD  147.33  148.16  146.90  148.16   241459.79
# 2019-12-01 03:00:00  ETHUSD  146.82  147.57  145.97  147.33   485601.54
# 2019-12-01 02:00:00  ETHUSD  148.59  149.18  146.55  146.82   838826.08
# 2019-12-01 01:00:00  ETHUSD  150.78  150.96  148.01  148.59   496816.36
# 2019-12-01 00:00:00  ETHUSD  151.78  151.78  150.51  150.78   407029.11
#
#                     DayOfWeek
# Date
# 2019-12-31 23:00:00   Tuesday
# 2019-12-31 22:00:00   Tuesday
# 2019-12-31 21:00:00   Tuesday
# 2019-12-31 20:00:00   Tuesday
# 2019-12-31 19:00:00   Tuesday
# ...                       ...
# 2019-12-01 04:00:00    Sunday
# 2019-12-01 03:00:00    Sunday
# 2019-12-01 02:00:00    Sunday
# 2019-12-01 01:00:00    Sunday
# 2019-12-01 00:00:00    Sunday
#
# [744 rows x 7 columns]

# %%
df.loc['2020-01':'2020-02']
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-02-29 23:00:00  ETHUSD  223.35  223.58  216.83  217.31  1927939.88
# 2020-02-29 22:00:00  ETHUSD  223.48  223.59  222.14  223.35   535998.57
# 2020-02-29 21:00:00  ETHUSD  224.63  225.14  222.74  223.48   561158.03
# 2020-02-29 20:00:00  ETHUSD  225.31  225.33  223.50  224.63   511648.65
# 2020-02-29 19:00:00  ETHUSD  225.09  225.85  223.87  225.31  1250856.20
# ...                     ...     ...     ...     ...     ...         ...
# 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#                      DayOfWeek
# Date
# 2020-02-29 23:00:00   Saturday
# 2020-02-29 22:00:00   Saturday
# 2020-02-29 21:00:00   Saturday
# 2020-02-29 20:00:00   Saturday
# 2020-02-29 19:00:00   Saturday
# ...                        ...
# 2020-01-01 04:00:00  Wednesday
# 2020-01-01 03:00:00  Wednesday
# 2020-01-01 02:00:00  Wednesday
# 2020-01-01 01:00:00  Wednesday
# 2020-01-01 00:00:00  Wednesday
#
# [1440 rows x 7 columns]

# %%
df.loc['2020-01':'2020-02']['Close'].mean()
# Out:
# 195.1655902777778

# %%
df.loc['2020-01-01']['High'].max()
# Out:
# 132.68

# %%
highs = df['High'].resample('D').max()
highs['2020-01-01']
# Out:
# 132.68

# %%
# %matplotlib inline

# %%
highs.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.resample('W').mean()
# Out:
#                   Open        High         Low       Close        Volume
# Date
# 2017-07-02  268.066486  271.124595  264.819730  268.202162  2.185035e+06
# 2017-07-09  261.337024  262.872917  259.186190  261.062083  1.337349e+06
# 2017-07-16  196.193214  199.204405  192.722321  195.698393  2.986756e+06
# 2017-07-23  212.351429  215.779286  209.126310  212.783750  4.298593e+06
# 2017-07-30  203.496190  205.110357  201.714048  203.309524  1.581729e+06
# ...                ...         ...         ...         ...           ...
# 2020-02-16  255.021667  257.255238  252.679762  255.198452  2.329087e+06
# 2020-02-23  265.220833  267.263690  262.948512  265.321905  1.826094e+06
# 2020-03-01  236.720536  238.697500  234.208750  236.373988  2.198762e+06
# 2020-03-08  229.923571  231.284583  228.373810  229.817619  1.628910e+06
# 2020-03-15  176.937521  179.979487  172.936239  176.332821  4.259828e+06
#
# [142 rows x 5 columns]

# %%
df.resample('W').agg({'Close': 'mean', 'High': 'max', 'Low': 'mean', 'Volume': 'sum'})
# Out:
#                  Close    High         Low        Volume
# Date
# 2017-07-02  268.202162  293.73  264.819730  8.084631e+07
# 2017-07-09  261.062083  285.00  259.186190  2.246746e+08
# 2017-07-16  195.698393  240.33  192.722321  5.017750e+08
# 2017-07-23  212.783750  249.40  209.126310  7.221637e+08
# 2017-07-30  203.309524  229.99  201.714048  2.657305e+08
# ...                ...     ...         ...           ...
# 2020-02-16  255.198452  290.00  252.679762  3.912867e+08
# 2020-02-23  265.321905  287.13  262.948512  3.067838e+08
# 2020-03-01  236.373988  278.13  234.208750  3.693920e+08
# 2020-03-08  229.817619  253.01  228.373810  2.736569e+08
# 2020-03-15  176.332821  208.65  172.936239  4.983998e+08
#
# [142 rows x 4 columns]

# %%
import pandas as pd
df = pd.read_csv('data/survey_results_public.csv', index_col='ResponseId')

# %%
filt = (df['Country'] == 'India')
india_df = df.loc[filt]

# %%
india_df.head()
# Out:
#                                         MainBranch          Employment  \
# ResponseId
# 9                   I am a developer by profession  Employed part-time
# 23          I am a student who is learning to code  Student, full-time
# 40          I am a student who is learning to code  Student, part-time
# 50          I am a student who is learning to code  Student, full-time
# 53                  I am a developer by profession  Employed full-time
#
#            Country US_State UK_Country  \
# ResponseId
# 9            India      NaN        NaN
# 23           India      NaN        NaN
# 40           India      NaN        NaN
# 50           India      NaN        NaN
# 53           India      NaN        NaN
#
#                                                       EdLevel     Age1stCode  \
# ResponseId
# 9                Bachelor’s degree (B.A., B.S., B.Eng., etc.)  18 - 24 years
# 23          Some college/university study without earning ...   5 - 10 years
# 40               Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 50          Some college/university study without earning ...  11 - 17 years
# 53            Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  11 - 17 years
#
#                                                     LearnCode YearsCode  \
# ResponseId
# 9                                             Coding Bootcamp         6
# 23                             School;Friend or family member         7
# 40                                                     School         3
# 50          Coding Bootcamp;Other online resources (ex: vi...       NaN
# 53          Other online resources (ex: videos, blogs, etc...         5
#
#            YearsCodePro  ...                 Age Gender Trans  \
# ResponseId               ...
# 9                     4  ...     25-34 years old    Man    No
# 23                  NaN  ...  Under 18 years old    Man    No
# 40                  NaN  ...     18-24 years old  Woman    No
# 50                  NaN  ...     18-24 years old    Man    No
# 53                    4  ...     25-34 years old    Man    No
#
#                           Sexuality                     Ethnicity  \
# ResponseId
# 9                               NaN                   South Asian
# 23                Prefer not to say             Prefer not to say
# 40          Straight / Heterosexual  White or of European descent
# 50          Straight / Heterosexual                   South Asian
# 53                Prefer not to say                  I don't know
#
#                 Accessibility  \
# ResponseId
# 9                         NaN
# 23          None of the above
# 40          None of the above
# 50          None of the above
# 53          None of the above
#
#                                                  MentalHealth  \
# ResponseId
# 9           I have a concentration and/or memory disorder ...
# 23                                          None of the above
# 40          I have a concentration and/or memory disorder ...
# 50                                          None of the above
# 53                                          None of the above
#
#                      SurveyLength                  SurveyEase  \
# ResponseId
# 9           Appropriate in length                        Easy
# 23          Appropriate in length                        Easy
# 40          Appropriate in length                        Easy
# 50          Appropriate in length                        Easy
# 53                       Too long  Neither easy nor difficult
#
#            ConvertedCompYearly
# ResponseId
# 9                          NaN
# 23                         NaN
# 40                         NaN
# 50                         NaN
# 53                         NaN
#
# [5 rows x 47 columns]

# %%
india_df.to_csv('data/modified.csv')

# %%
india_df.to_csv('data/modified.tsv', sep='\t')

# %%
india_df.to_excel('data/modified.xlsx')

# %%
test = pd.read_excel('data/modified.xlsx', index_col='ResponseId')

# %%
test.head()
# Out:
#                                         MainBranch          Employment  \
# ResponseId
# 9                   I am a developer by profession  Employed part-time
# 23          I am a student who is learning to code  Student, full-time
# 40          I am a student who is learning to code  Student, part-time
# 50          I am a student who is learning to code  Student, full-time
# 53                  I am a developer by profession  Employed full-time
#
#            Country  US_State  UK_Country  \
# ResponseId
# 9            India       NaN         NaN
# 23           India       NaN         NaN
# 40           India       NaN         NaN
# 50           India       NaN         NaN
# 53           India       NaN         NaN
#
#                                                       EdLevel     Age1stCode  \
# ResponseId
# 9                Bachelor’s degree (B.A., B.S., B.Eng., etc.)  18 - 24 years
# 23          Some college/university study without earning ...   5 - 10 years
# 40               Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 50          Some college/university study without earning ...  11 - 17 years
# 53            Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  11 - 17 years
#
#                                                     LearnCode YearsCode  \
# ResponseId
# 9                                             Coding Bootcamp         6
# 23                             School;Friend or family member         7
# 40                                                     School         3
# 50          Coding Bootcamp;Other online resources (ex: vi...       NaN
# 53          Other online resources (ex: videos, blogs, etc...         5
#
#            YearsCodePro  ...                 Age Gender Trans  \
# ResponseId               ...
# 9                     4  ...     25-34 years old    Man    No
# 23                  NaN  ...  Under 18 years old    Man    No
# 40                  NaN  ...     18-24 years old  Woman    No
# 50                  NaN  ...     18-24 years old    Man    No
# 53                    4  ...     25-34 years old    Man    No
#
#                           Sexuality                     Ethnicity  \
# ResponseId
# 9                               NaN                   South Asian
# 23                Prefer not to say             Prefer not to say
# 40          Straight / Heterosexual  White or of European descent
# 50          Straight / Heterosexual                   South Asian
# 53                Prefer not to say                  I don't know
#
#                 Accessibility  \
# ResponseId
# 9                         NaN
# 23          None of the above
# 40          None of the above
# 50          None of the above
# 53          None of the above
#
#                                                  MentalHealth  \
# ResponseId
# 9           I have a concentration and/or memory disorder ...
# 23                                          None of the above
# 40          I have a concentration and/or memory disorder ...
# 50                                          None of the above
# 53                                          None of the above
#
#                      SurveyLength                  SurveyEase  \
# ResponseId
# 9           Appropriate in length                        Easy
# 23          Appropriate in length                        Easy
# 40          Appropriate in length                        Easy
# 50          Appropriate in length                        Easy
# 53                       Too long  Neither easy nor difficult
#
#            ConvertedCompYearly
# ResponseId
# 9                          NaN
# 23                         NaN
# 40                         NaN
# 50                         NaN
# 53                         NaN
#
# [5 rows x 47 columns]

# %%
india_df.to_json('data/modified.json', orient='records', lines=True)

# %%
test = pd.read_json('data/modified.json', orient='records', lines=True)

# %%
test.head()
# Out:
#                                MainBranch          Employment Country  \
# 0          I am a developer by profession  Employed part-time   India
# 1  I am a student who is learning to code  Student, full-time   India
# 2  I am a student who is learning to code  Student, part-time   India
# 3  I am a student who is learning to code  Student, full-time   India
# 4          I am a developer by profession  Employed full-time   India
#
#    US_State  UK_Country                                            EdLevel  \
# 0       NaN         NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 1       NaN         NaN  Some college/university study without earning ...
# 2       NaN         NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3       NaN         NaN  Some college/university study without earning ...
# 4       NaN         NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#       Age1stCode                                          LearnCode YearsCode  \
# 0  18 - 24 years                                    Coding Bootcamp         6
# 1   5 - 10 years                     School;Friend or family member         7
# 2  11 - 17 years                                             School         3
# 3  11 - 17 years  Coding Bootcamp;Other online resources (ex: vi...      None
# 4  11 - 17 years  Other online resources (ex: videos, blogs, etc...         5
#
#   YearsCodePro  ...                 Age Gender Trans                Sexuality  \
# 0            4  ...     25-34 years old    Man    No                     None
# 1         None  ...  Under 18 years old    Man    No        Prefer not to say
# 2         None  ...     18-24 years old  Woman    No  Straight / Heterosexual
# 3         None  ...     18-24 years old    Man    No  Straight / Heterosexual
# 4            4  ...     25-34 years old    Man    No        Prefer not to say
#
#                       Ethnicity      Accessibility  \
# 0                   South Asian               None
# 1             Prefer not to say  None of the above
# 2  White or of European descent  None of the above
# 3                   South Asian  None of the above
# 4                  I don't know  None of the above
#
#                                         MentalHealth           SurveyLength  \
# 0  I have a concentration and/or memory disorder ...  Appropriate in length
# 1                                  None of the above  Appropriate in length
# 2  I have a concentration and/or memory disorder ...  Appropriate in length
# 3                                  None of the above  Appropriate in length
# 4                                  None of the above               Too long
#
#                    SurveyEase ConvertedCompYearly
# 0                        Easy                 NaN
# 1                        Easy                 NaN
# 2                        Easy                 NaN
# 3                        Easy                 NaN
# 4  Neither easy nor difficult                 NaN
#
# [5 rows x 47 columns]

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
engine = create_engine('postgresql://dbuser:dbpass@localhost:5432/sample_db')

# %%
india_df.to_sql('sample_table', engine, if_exists='replace')

# %%
sql_df = pd.read_sql('sample_table', engine, index_col='ResponseId')

# %%
sql_df = pd.read_sql_query('SELECT * FROM sample_table', engine, index_col='ResponseId')

# %%
posts_df = pd.read_json('...url...')

# %%
posts_df.head()
